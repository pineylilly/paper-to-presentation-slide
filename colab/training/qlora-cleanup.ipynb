# %%
from google.colab import userdata
api_key = userdata.get('gemini_api_key')

# %%
import google.generativeai as genai
from tqdm import tqdm

genai.configure(api_key=api_key)
generation_config = genai.GenerationConfig(
        temperature=0,
)
model = genai.GenerativeModel("gemini-2.0-flash-001", generation_config=generation_config)

# %%
from google.api_core import retry
from google.api_core import exceptions

# Catch transient Gemini errors.
def is_retryable(e) -> bool:
    if retry.if_transient_error(e):
        # Good practice, but probably won't fire with the google-genai SDK
        return True
    elif isinstance(e, exceptions.TooManyRequests):  # HTTP 429
        return True
    elif isinstance(e, exceptions.ServiceUnavailable):  # HTTP 503
        return True
    else:
        return False

@retry.Retry(predicate=is_retryable)
def generate_content_with_rate_limit(prompt):
  return model.generate_content(prompt).text

# %%
def remove_markdown_tag(text):
    return text.replace("```markdown", "").replace("```", "")

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/dataset-pdf-zip/dataset-pdf-20250430T213758Z-001.zip" .

# %%
# !rm -rf dataset-pdf

# %%
# !unzip "dataset-pdf-20250430T213758Z-001.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset-pdf/287/images/Figure_2.png
#   inflating: dataset-pdf/1041/images/Figure_3.png
#   inflating: dataset-pdf/1041/images/Figure_11.png
#   inflating: dataset-pdf/1041/images/Figure_6.png
#   inflating: dataset-pdf/1041/images/Figure_5.png
#   inflating: dataset-pdf/1041/images/Figure_2.png
#   inflating: dataset-pdf/222/images/Figure_5.png
#   inflating: dataset-pdf/1041/images/Figure_8.png
#   inflating: dataset-pdf/1041/images/Figure_9.png
#   inflating: dataset-pdf/106/paper.pdf
#   inflating: dataset-pdf/1041/images/Figure_7.png
#   inflating: dataset-pdf/156/images/Figure_7.png
#   inflating: dataset-pdf/1041/images/Figure_10.png
#   inflating: dataset-pdf/106/images/Figure_5.png
#   inflating: dataset-pdf/106/images/Figure_6.png
#   inflating: dataset-pdf/106/images/Figure_4.png
#   inflating: dataset-pdf/156/images/Figure_9.png
#   inflating: dataset-pdf/1041/images/Figure_4.png
#   inflating: dataset-pdf/333/paper.pdf
#   inflating: dataset-pdf/106/images/Table_IV.png
#   inflating: dataset-pdf/106/images/Table_I.png
#   inflating: dataset-pdf/156/images/Figure_2.png
#   inflating: dataset-pdf/106/images/Figure_2.png
#   inflating: dataset-pdf/156/images/Figure_5.png
#   inflating: dataset-pdf/156/images/Figure_3.png
#   inflating: dataset-pdf/156/images/Figure_4.png
#   inflating: dataset-pdf/156/images/Figure_8.png
#   inflating: dataset-pdf/156/images/Figure_6.png
#   inflating: dataset-pdf/187/extracted_text_with_tag.txt
#   inflating: dataset-pdf/156/images/Table_1.png
#   inflating: dataset-pdf/106/images/Figure_1.png
#   inflating: dataset-pdf/187/slide.xml
#   inflating: dataset-pdf/187/214.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/187/extracted_text.txt
#   inflating: dataset-pdf/187/paper.tei.xml
#   inflating: dataset-pdf/106/images/Figure_3.png
#   inflating: dataset-pdf/156/images/Figure_1.png
#   inflating: dataset-pdf/899/figures_and_tables.txt
#   inflating: dataset-pdf/187/input_prompt.txt
#   inflating: dataset-pdf/899/slide.md
#   inflating: dataset-pdf/187/slide.md
#   inflating: dataset-pdf/899/extracted_text.txt
#   inflating: dataset-pdf/106/slide.pdf
#   inflating: dataset-pdf/333/slide.pdf
#   inflating: dataset-pdf/187/figures_and_tables.txt
#   inflating: dataset-pdf/899/extracted_text_with_tag.txt
#   inflating: dataset-pdf/899/paper.tei.xml
#   inflating: dataset-pdf/899/slide.xml
#   inflating: dataset-pdf/899/input_prompt.txt
#   inflating: dataset-pdf/58/images/Figure_1.png
#   inflating: dataset-pdf/58/images/Table_7.png
#   inflating: dataset-pdf/683/input_prompt.txt
#   inflating: dataset-pdf/58/images/Figure_2.png
#   inflating: dataset-pdf/58/images/Figure_4.png
#   inflating: dataset-pdf/58/images/Figure_3.png
#   inflating: dataset-pdf/36/images/Figure_2.png
#   inflating: dataset-pdf/58/images/Table_6.png
#   inflating: dataset-pdf/187/paper.pdf
#   inflating: dataset-pdf/28/images/Figure_1.png
#   inflating: dataset-pdf/28/images/Figure_2.png
#   inflating: dataset-pdf/287/images/Table_1.png
#   inflating: dataset-pdf/583/slide.md
#   inflating: dataset-pdf/28/images/Figure_4.png
#   inflating: dataset-pdf/58/images/Table_9.png
#   inflating: dataset-pdf/899/paper.pdf
#   inflating: dataset-pdf/583/slide.xml
#   inflating: dataset-pdf/187/images/Figure_1.png
#   inflating: dataset-pdf/583/figures_and_tables.txt
#   inflating: dataset-pdf/899/slide.pdf
#   inflating: dataset-pdf/583/input_prompt.txt
#   inflating: dataset-pdf/28/images/Figure_5.png
#   inflating: dataset-pdf/28/images/Figure_3.png
#   inflating: dataset-pdf/583/extracted_text_with_tag.txt
#   inflating: dataset-pdf/583/696.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/899/1087.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/583/paper.pdf
#   inflating: dataset-pdf/36/images/Figure_1.png
#   inflating: dataset-pdf/275/paper.tei.xml
#    creating: dataset-pdf/899/images/
#   inflating: dataset-pdf/275/322.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/220/images/Figure_1.png
#   inflating: dataset-pdf/275/input_prompt.txt
#   inflating: dataset-pdf/275/slide.xml
#   inflating: dataset-pdf/187/slide.pdf
#   inflating: dataset-pdf/275/images/Table_3.png
#   inflating: dataset-pdf/275/extracted_text_with_tag.txt
#   inflating: dataset-pdf/275/extracted_text.txt
#   inflating: dataset-pdf/275/images/Table_4.png
#   inflating: dataset-pdf/275/slide.pdf
#   inflating: dataset-pdf/275/figures_and_tables.txt
#   inflating: dataset-pdf/583/paper.tei.xml
#   inflating: dataset-pdf/275/images/Figure_3.png
#   inflating: dataset-pdf/275/slide.md
#   inflating: dataset-pdf/275/images/Figure_1.png
#   inflating: dataset-pdf/377/images/Figure_3.png
#   inflating: dataset-pdf/377/images/Figure_2.png
#   inflating: dataset-pdf/275/images/Table_2.png
#   inflating: dataset-pdf/275/images/Table_5.png
#   inflating: dataset-pdf/377/images/Table_1.png
#   inflating: dataset-pdf/377/images/Figure_6.png
#   inflating: dataset-pdf/377/images/Table_3.png
#   inflating: dataset-pdf/275/paper.pdf
#   inflating: dataset-pdf/377/images/Table_2.png
#   inflating: dataset-pdf/583/extracted_text.txt
#   inflating: dataset-pdf/583/slide.pdf
#   inflating: dataset-pdf/683/extracted_text.txt
#   inflating: dataset-pdf/377/images/Figure_4.png
#   inflating: dataset-pdf/377/images/Table_5.png
#   inflating: dataset-pdf/301/slide.md
#   inflating: dataset-pdf/683/slide.md
#   inflating: dataset-pdf/377/images/Table_4.png
#   inflating: dataset-pdf/377/images/Figure_1.png
#   inflating: dataset-pdf/377/images/Figure_5.png
#   inflating: dataset-pdf/38/44.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/38/extracted_text_with_tag.txt
#   inflating: dataset-pdf/38/slide.xml
#   inflating: dataset-pdf/393/images/Figure_9.png
#   inflating: dataset-pdf/38/extracted_text.txt
#   inflating: dataset-pdf/38/slide.md
#   inflating: dataset-pdf/393/images/Figure_4.png
#   inflating: dataset-pdf/38/paper.tei.xml
#   inflating: dataset-pdf/393/images/Table_2.png
#   inflating: dataset-pdf/38/input_prompt.txt
#   inflating: dataset-pdf/393/images/Figure_8.png
#   inflating: dataset-pdf/393/images/Figure_6.png
#   inflating: dataset-pdf/393/images/Table_1.png
#   inflating: dataset-pdf/38/slide.pdf
#   inflating: dataset-pdf/38/figures_and_tables.txt
#   inflating: dataset-pdf/393/images/Figure_1.png
#   inflating: dataset-pdf/393/images/Figure_3.png
#   inflating: dataset-pdf/393/images/Table_3.png
#   inflating: dataset-pdf/393/images/Figure_5.png
#   inflating: dataset-pdf/393/images/Figure_2.png
#   inflating: dataset-pdf/319/paper.tei.xml
#   inflating: dataset-pdf/319/slide.xml
#   inflating: dataset-pdf/107/figures_and_tables.txt
#   inflating: dataset-pdf/107/slide.xml
#   inflating: dataset-pdf/319/slide.md
#   inflating: dataset-pdf/107/122.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/319/extracted_text.txt
#   inflating: dataset-pdf/107/paper.tei.xml
#   inflating: dataset-pdf/319/figures_and_tables.txt
#   inflating: dataset-pdf/319/extracted_text_with_tag.txt
#   inflating: dataset-pdf/319/383.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/107/extracted_text_with_tag.txt
#   inflating: dataset-pdf/107/slide.pdf
#   inflating: dataset-pdf/107/extracted_text.txt
#   inflating: dataset-pdf/319/paper.pdf
#   inflating: dataset-pdf/319/input_prompt.txt
#   inflating: dataset-pdf/38/paper.pdf
#   inflating: dataset-pdf/930/slide.md
#   inflating: dataset-pdf/930/1124.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/930/extracted_text_with_tag.txt
#   inflating: dataset-pdf/930/input_prompt.txt
#   inflating: dataset-pdf/930/slide.xml
#   inflating: dataset-pdf/930/figures_and_tables.txt
#   inflating: dataset-pdf/930/extracted_text.txt
#   inflating: dataset-pdf/583/images/Table_3.png
#   inflating: dataset-pdf/930/paper.tei.xml
#   inflating: dataset-pdf/319/slide.pdf
#   inflating: dataset-pdf/583/images/Figure_2.png
#   inflating: dataset-pdf/107/input_prompt.txt
#   inflating: dataset-pdf/107/slide.md
#   inflating: dataset-pdf/583/images/Table_2.png
#   inflating: dataset-pdf/583/images/Figure_3.png
#   inflating: dataset-pdf/38/images/Table_2.png
#   inflating: dataset-pdf/107/paper.pdf
#   inflating: dataset-pdf/38/images/Table_3.png
#   inflating: dataset-pdf/38/images/Table_1.png
#   inflating: dataset-pdf/38/images/Figure_1.png
#   inflating: dataset-pdf/18/extracted_text_with_tag.txt
#   inflating: dataset-pdf/18/21.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/583/images/Figure_1.png
#   inflating: dataset-pdf/18/slide.xml
#   inflating: dataset-pdf/38/images/Table_4.png
#   inflating: dataset-pdf/583/images/Table_1.png
#   inflating: dataset-pdf/18/extracted_text.txt
#   inflating: dataset-pdf/930/paper.pdf
#   inflating: dataset-pdf/244/images/Figure_2.png
#   inflating: dataset-pdf/38/images/Figure_2.png
#   inflating: dataset-pdf/244/images/Figure_5.png
#   inflating: dataset-pdf/244/images/Figure_4.png
#   inflating: dataset-pdf/18/input_prompt.txt
#   inflating: dataset-pdf/244/images/Figure_7.png
#   inflating: dataset-pdf/414/images/Figure_1.png
#   inflating: dataset-pdf/18/figures_and_tables.txt
#   inflating: dataset-pdf/244/images/Figure_6.png
#   inflating: dataset-pdf/18/slide.md
#   inflating: dataset-pdf/414/images/Figure_3.png
#   inflating: dataset-pdf/18/paper.tei.xml
#   inflating: dataset-pdf/414/images/Table_1.png
#   inflating: dataset-pdf/86/images/Table_4.png
#   inflating: dataset-pdf/244/images/Figure_3.png
#   inflating: dataset-pdf/244/images/Figure_1.png
#   inflating: dataset-pdf/86/images/Figure_1.png
#   inflating: dataset-pdf/930/slide.pdf
#   inflating: dataset-pdf/86/images/Table_5.png
#   inflating: dataset-pdf/18/paper.pdf
#   inflating: dataset-pdf/86/images/Table_2.png
#   inflating: dataset-pdf/86/images/Figure_5.png
#   inflating: dataset-pdf/86/images/Figure_2.png
#   inflating: dataset-pdf/86/images/Figure_4.png
#   inflating: dataset-pdf/86/images/Figure_3.png
#   inflating: dataset-pdf/86/images/Table_8.png
#   inflating: dataset-pdf/319/images/Figure_5.png
#   inflating: dataset-pdf/319/images/Figure_4.png
#   inflating: dataset-pdf/86/images/Figure_6.png
#   inflating: dataset-pdf/18/slide.pdf
#   inflating: dataset-pdf/86/images/Table_3.png
#   inflating: dataset-pdf/319/images/Figure_1.png
#   inflating: dataset-pdf/319/images/Figure_7.png
#   inflating: dataset-pdf/86/images/Table_7.png
#   inflating: dataset-pdf/86/images/Table_6.png
#   inflating: dataset-pdf/319/images/Figure_3.png
#   inflating: dataset-pdf/319/images/Table_1.png
#   inflating: dataset-pdf/673/slide.xml
#   inflating: dataset-pdf/319/images/Figure_8.png
#   inflating: dataset-pdf/673/input_prompt.txt
#   inflating: dataset-pdf/319/images/Figure_6.png
#   inflating: dataset-pdf/319/images/Figure_2.png
#   inflating: dataset-pdf/673/extracted_text_with_tag.txt
#   inflating: dataset-pdf/673/figures_and_tables.txt
#   inflating: dataset-pdf/683/images/Table_11.png
#   inflating: dataset-pdf/673/805.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/683/images/Table_5.png
#   inflating: dataset-pdf/673/paper.tei.xml
#   inflating: dataset-pdf/683/images/Figure_3.png
#   inflating: dataset-pdf/683/images/Table_10.png
#   inflating: dataset-pdf/673/slide.pdf
#   inflating: dataset-pdf/673/slide.md
#   inflating: dataset-pdf/673/extracted_text.txt
#   inflating: dataset-pdf/1065/images/Table_5.png
#   inflating: dataset-pdf/683/images/Table_7.png
#   inflating: dataset-pdf/683/images/Table_4.png
#   inflating: dataset-pdf/1065/images/Figure_7.png
#   inflating: dataset-pdf/683/images/Table_3.png
#   inflating: dataset-pdf/1065/images/Table_3.png
#   inflating: dataset-pdf/1065/images/Figure_4.png
#   inflating: dataset-pdf/683/images/Table_8.png
#   inflating: dataset-pdf/1065/images/Table_1.png
#   inflating: dataset-pdf/1065/images/Figure_9.png
#   inflating: dataset-pdf/683/images/Table_1.png
#   inflating: dataset-pdf/683/images/Table_2.png
#   inflating: dataset-pdf/1065/images/Figure_13.png
#   inflating: dataset-pdf/683/images/Table_9.png
#   inflating: dataset-pdf/683/images/Table_6.png
#   inflating: dataset-pdf/1065/images/Figure_5.png
#   inflating: dataset-pdf/1065/images/Table_12.png
#   inflating: dataset-pdf/683/images/Figure_2.png
#   inflating: dataset-pdf/1065/images/Table_2.png
#   inflating: dataset-pdf/1065/images/Table_7.png
#   inflating: dataset-pdf/673/paper.pdf
#   inflating: dataset-pdf/683/images/Figure_1.png
#   inflating: dataset-pdf/1065/images/Figure_1.png
#   inflating: dataset-pdf/1065/images/Figure_2.png
#   inflating: dataset-pdf/1065/images/Figure_10.png
#   inflating: dataset-pdf/1065/images/Table_10.png
#   inflating: dataset-pdf/1065/images/Table_9.png
#   inflating: dataset-pdf/1065/images/Figure_3.png
#   inflating: dataset-pdf/723/figures_and_tables.txt
#   inflating: dataset-pdf/1065/images/Table_11.png
#   inflating: dataset-pdf/1065/images/Figure_14.png
#   inflating: dataset-pdf/723/slide.xml
#   inflating: dataset-pdf/723/input_prompt.txt
#   inflating: dataset-pdf/1065/images/Table_13.png
#   inflating: dataset-pdf/1065/images/Figure_12.png
#   inflating: dataset-pdf/723/paper.tei.xml
#   inflating: dataset-pdf/1065/images/Table_6.png
#   inflating: dataset-pdf/1065/images/Table_4.png
#   inflating: dataset-pdf/1065/images/Figure_6.png
#   inflating: dataset-pdf/44/images/Figure_5.png
#    creating: dataset-pdf/349/images/
#   inflating: dataset-pdf/723/slide.md
#   inflating: dataset-pdf/723/extracted_text_with_tag.txt
#   inflating: dataset-pdf/1065/images/Figure_11.png
#   inflating: dataset-pdf/44/images/Figure_3.png
#   inflating: dataset-pdf/1065/images/Figure_15.png
#   inflating: dataset-pdf/414/images/Table_2.png
#   inflating: dataset-pdf/723/slide.pdf
#   inflating: dataset-pdf/1065/images/Figure_8.png
#   inflating: dataset-pdf/65/figures_and_tables.txt
#   inflating: dataset-pdf/723/paper.pdf
#   inflating: dataset-pdf/44/images/Figure_7.png
#   inflating: dataset-pdf/723/868.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/65/slide.md
#   inflating: dataset-pdf/65/slide.pdf
#   inflating: dataset-pdf/414/images/Figure_2.png
#   inflating: dataset-pdf/44/images/Table_1.png
#   inflating: dataset-pdf/414/images/Figure_4.png
#   inflating: dataset-pdf/1065/images/Table_8.png
#   inflating: dataset-pdf/65/extracted_text_with_tag.txt
#   inflating: dataset-pdf/44/images/Figure_6.png
#   inflating: dataset-pdf/65/74.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/333/images/Figure_2.png
#   inflating: dataset-pdf/44/images/Figure_4.png
#   inflating: dataset-pdf/224/paper.tei.xml
#   inflating: dataset-pdf/723/extracted_text.txt
#   inflating: dataset-pdf/333/images/Figure_7.png
#   inflating: dataset-pdf/65/input_prompt.txt
#   inflating: dataset-pdf/65/paper.tei.xml
#   inflating: dataset-pdf/65/slide.xml
#   inflating: dataset-pdf/249/images/Figure_2.png
#   inflating: dataset-pdf/65/extracted_text.txt
#   inflating: dataset-pdf/333/images/Figure_6.png
#   inflating: dataset-pdf/333/images/Figure_3.png
#   inflating: dataset-pdf/249/images/Figure_9.png
#   inflating: dataset-pdf/249/images/Figure_1.png
#   inflating: dataset-pdf/333/images/Figure_5.png
#   inflating: dataset-pdf/249/images/Figure_4.png
#   inflating: dataset-pdf/333/images/Figure_4.png
#   inflating: dataset-pdf/249/images/Figure_5.png
#   inflating: dataset-pdf/249/images/Figure_11.png
#   inflating: dataset-pdf/249/images/Figure_6.png
#   inflating: dataset-pdf/333/images/Figure_1.png
#   inflating: dataset-pdf/48/extracted_text.txt
#   inflating: dataset-pdf/65/paper.pdf
#   inflating: dataset-pdf/249/images/Figure_12.png
#   inflating: dataset-pdf/333/images/Table_1.png
#   inflating: dataset-pdf/249/images/Figure_8.png
#   inflating: dataset-pdf/973/paper.pdf
#   inflating: dataset-pdf/249/images/Figure_10.png
#   inflating: dataset-pdf/372/slide.xml
#   inflating: dataset-pdf/249/images/Figure_3.png
#   inflating: dataset-pdf/372/figures_and_tables.txt
#   inflating: dataset-pdf/372/input_prompt.txt
#   inflating: dataset-pdf/372/paper.pdf
#   inflating: dataset-pdf/372/extracted_text_with_tag.txt
#   inflating: dataset-pdf/372/448.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/372/extracted_text.txt
#   inflating: dataset-pdf/723/images/Table_5.png
#   inflating: dataset-pdf/723/images/Table_4.png
#   inflating: dataset-pdf/372/paper.tei.xml
#   inflating: dataset-pdf/723/images/Table_2.png
#   inflating: dataset-pdf/544/slide.xml
#   inflating: dataset-pdf/372/slide.md
#   inflating: dataset-pdf/723/images/Table_1.png
#   inflating: dataset-pdf/544/figures_and_tables.txt
#   inflating: dataset-pdf/723/images/Figure_3.png
#   inflating: dataset-pdf/723/images/Table_3.png
#   inflating: dataset-pdf/544/extracted_text_with_tag.txt
#   inflating: dataset-pdf/544/652.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/544/extracted_text.txt
#   inflating: dataset-pdf/544/input_prompt.txt
#   inflating: dataset-pdf/723/images/Figure_1.png
#   inflating: dataset-pdf/372/slide.pdf
#   inflating: dataset-pdf/723/images/Figure_2.png
#   inflating: dataset-pdf/216/input_prompt.txt
#    creating: dataset-pdf/63/images/
#   inflating: dataset-pdf/216/paper.tei.xml
#   inflating: dataset-pdf/544/slide.md
#   inflating: dataset-pdf/216/figures_and_tables.txt
#   inflating: dataset-pdf/216/slide.md
#   inflating: dataset-pdf/544/paper.tei.xml
#   inflating: dataset-pdf/143/images/Figure_8.png
#   inflating: dataset-pdf/216/slide.pdf
#   inflating: dataset-pdf/216/extracted_text.txt
#   inflating: dataset-pdf/216/slide.xml
#   inflating: dataset-pdf/143/images/Figure_9.png
#   inflating: dataset-pdf/143/images/Figure_3.png
#   inflating: dataset-pdf/216/extracted_text_with_tag.txt
#   inflating: dataset-pdf/544/slide.pdf
#   inflating: dataset-pdf/143/images/Figure_4.png
#   inflating: dataset-pdf/143/images/Figure_6.png
#   inflating: dataset-pdf/592/images/Figure_3.png
#   inflating: dataset-pdf/143/images/Figure_5.png
#   inflating: dataset-pdf/592/images/Figure_8.png
#   inflating: dataset-pdf/143/images/Figure_1.png
#   inflating: dataset-pdf/592/images/Figure_7.png
#   inflating: dataset-pdf/216/254.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/143/images/Figure_2.png
#   inflating: dataset-pdf/143/images/Figure_11.png
#   inflating: dataset-pdf/509/images/Figure_1.png
#   inflating: dataset-pdf/544/paper.pdf
#   inflating: dataset-pdf/592/images/Figure_11.png
#   inflating: dataset-pdf/509/images/Table_II.png
#   inflating: dataset-pdf/143/images/Figure_12.png
#   inflating: dataset-pdf/126/slide.xml
#   inflating: dataset-pdf/592/images/Figure_1.png
#   inflating: dataset-pdf/126/slide.pdf
#   inflating: dataset-pdf/509/images/Table_III.png
#   inflating: dataset-pdf/757/images/Figure_2.png
#   inflating: dataset-pdf/126/slide.md
#   inflating: dataset-pdf/126/extracted_text_with_tag.txt
#   inflating: dataset-pdf/757/images/Figure_7.png
#   inflating: dataset-pdf/126/figures_and_tables.txt
#   inflating: dataset-pdf/757/images/Figure_3.png
#   inflating: dataset-pdf/757/images/Figure_5.png
#   inflating: dataset-pdf/757/images/Figure_1.png
#   inflating: dataset-pdf/126/input_prompt.txt
#   inflating: dataset-pdf/126/144.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/126/extracted_text.txt
#   inflating: dataset-pdf/216/paper.pdf
#   inflating: dataset-pdf/757/images/Figure_15.png
#   inflating: dataset-pdf/592/images/Figure_9.png
#   inflating: dataset-pdf/126/paper.tei.xml
#    creating: dataset-pdf/65/images/
#   inflating: dataset-pdf/757/images/Figure_19.png
#   inflating: dataset-pdf/757/images/Figure_13.png
#   inflating: dataset-pdf/757/images/Figure_8.png
#   inflating: dataset-pdf/757/images/Figure_10.png
#   inflating: dataset-pdf/757/images/Figure_12.png
#   inflating: dataset-pdf/757/images/Figure_6.png
#   inflating: dataset-pdf/381/images/Figure_9.png
#   inflating: dataset-pdf/381/images/Figure_2.png
#   inflating: dataset-pdf/381/images/Figure_3.png
#   inflating: dataset-pdf/381/images/Table_2.png
#   inflating: dataset-pdf/381/images/Figure_5.png
#   inflating: dataset-pdf/757/images/Figure_16.png
#   inflating: dataset-pdf/126/paper.pdf
#   inflating: dataset-pdf/126/images/Figure_7.png
#   inflating: dataset-pdf/381/images/Figure_8.png
#   inflating: dataset-pdf/381/images/Figure_12.png
#   inflating: dataset-pdf/381/images/Table_1.png
#   inflating: dataset-pdf/381/images/Figure_14.png
#   inflating: dataset-pdf/381/images/Figure_13.png
#   inflating: dataset-pdf/381/images/Figure_1.png
#   inflating: dataset-pdf/381/images/Figure_6.png
#   inflating: dataset-pdf/592/images/Figure_5.png
#   inflating: dataset-pdf/381/images/Figure_7.png
#   inflating: dataset-pdf/381/images/Figure_4.png
#   inflating: dataset-pdf/381/images/Figure_10.png
#   inflating: dataset-pdf/126/images/Table_2.png
#   inflating: dataset-pdf/126/images/Figure_5.png
#   inflating: dataset-pdf/126/images/Table_1.png
#   inflating: dataset-pdf/126/images/Table_3.png
#   inflating: dataset-pdf/126/images/Figure_3.png
#   inflating: dataset-pdf/126/images/Figure_4.png
#   inflating: dataset-pdf/105/paper.tei.xml
#   inflating: dataset-pdf/126/images/Figure_1.png
#   inflating: dataset-pdf/381/images/Figure_11.png
#   inflating: dataset-pdf/105/input_prompt.txt
#   inflating: dataset-pdf/865/images/Table_3.png
#   inflating: dataset-pdf/865/images/Table_1.png
#   inflating: dataset-pdf/105/120.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/105/slide.md
#   inflating: dataset-pdf/865/images/Figure_3.png
#   inflating: dataset-pdf/105/slide.xml
#   inflating: dataset-pdf/105/extracted_text.txt
#   inflating: dataset-pdf/105/extracted_text_with_tag.txt
#   inflating: dataset-pdf/865/images/Figure_9.png
#   inflating: dataset-pdf/865/images/Table_2.png
#   inflating: dataset-pdf/865/images/Figure_7.png
#   inflating: dataset-pdf/105/figures_and_tables.txt
#   inflating: dataset-pdf/865/images/Figure_11.png
#   inflating: dataset-pdf/865/images/Figure_4.png
#   inflating: dataset-pdf/865/images/Figure_8.png
#   inflating: dataset-pdf/865/images/Figure_6.png
#   inflating: dataset-pdf/31/slide.md
#   inflating: dataset-pdf/865/images/Figure_10.png
#   inflating: dataset-pdf/865/images/Figure_5.png
#   inflating: dataset-pdf/105/slide.pdf
#   inflating: dataset-pdf/31/input_prompt.txt
#   inflating: dataset-pdf/31/figures_and_tables.txt
#   inflating: dataset-pdf/31/extracted_text_with_tag.txt
#   inflating: dataset-pdf/31/slide.xml
#   inflating: dataset-pdf/31/37.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/105/paper.pdf
#   inflating: dataset-pdf/12/images/Figure_2.png
#   inflating: dataset-pdf/31/extracted_text.txt
#   inflating: dataset-pdf/31/paper.tei.xml
#   inflating: dataset-pdf/105/images/Figure_4.png
#   inflating: dataset-pdf/12/images/Figure_7.png
#   inflating: dataset-pdf/31/paper.pdf
#   inflating: dataset-pdf/12/images/Figure_6.png
#   inflating: dataset-pdf/105/images/Figure_2.png
#   inflating: dataset-pdf/105/images/Figure_8.png
#   inflating: dataset-pdf/12/images/Figure_5.png
#   inflating: dataset-pdf/1097/slide.xml
#   inflating: dataset-pdf/105/images/Figure_1.png
#   inflating: dataset-pdf/31/slide.pdf
#   inflating: dataset-pdf/12/images/Figure_3.png
#   inflating: dataset-pdf/12/images/Figure_1.png
#   inflating: dataset-pdf/105/images/Figure_3.png
#   inflating: dataset-pdf/31/images/Figure_1.png
#   inflating: dataset-pdf/31/images/Figure_3.png
#   inflating: dataset-pdf/1097/input_prompt.txt
#   inflating: dataset-pdf/1097/figures_and_tables.txt
#   inflating: dataset-pdf/105/images/Figure_6.png
#   inflating: dataset-pdf/1097/extracted_text_with_tag.txt
#   inflating: dataset-pdf/1097/slide.md
#   inflating: dataset-pdf/12/images/Figure_4.png
#   inflating: dataset-pdf/245/images/Figure_2.png
#   inflating: dataset-pdf/245/images/Table_1.png
#   inflating: dataset-pdf/1097/1314.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/1097/extracted_text.txt
#   inflating: dataset-pdf/1097/images/Figure_14.png
#   inflating: dataset-pdf/245/images/Figure_7.png
#   inflating: dataset-pdf/245/images/Figure_1.png
#   inflating: dataset-pdf/1097/paper.tei.xml
#   inflating: dataset-pdf/1097/images/Figure_1.png
#   inflating: dataset-pdf/1097/images/Figure_13.png
#   inflating: dataset-pdf/1097/images/Figure_19.png
#   inflating: dataset-pdf/1097/images/Figure_9.png
#   inflating: dataset-pdf/1097/images/Table_2.png
#   inflating: dataset-pdf/245/images/Figure_5.png
#   inflating: dataset-pdf/245/images/Figure_3.png
#   inflating: dataset-pdf/245/images/Table_2.png
#   inflating: dataset-pdf/245/images/Figure_4.png
#   inflating: dataset-pdf/1097/images/Figure_12.png
#   inflating: dataset-pdf/1097/images/Figure_17.png
#   inflating: dataset-pdf/1097/images/Figure_5.png
#   inflating: dataset-pdf/1097/paper.pdf
#   inflating: dataset-pdf/1097/images/Figure_2.png
#   inflating: dataset-pdf/1097/images/Figure_11.png
#   inflating: dataset-pdf/1097/images/Figure_7.png
#   inflating: dataset-pdf/1097/images/Figure_15.png
#   inflating: dataset-pdf/1097/images/Figure_8.png
#   inflating: dataset-pdf/1097/images/Figure_16.png
#   inflating: dataset-pdf/1097/slide.pdf
#   inflating: dataset-pdf/1097/images/Figure_18.png
#   inflating: dataset-pdf/1097/images/Figure_23.png
#   inflating: dataset-pdf/245/images/Figure_6.png
#   inflating: dataset-pdf/678/slide.xml
#   inflating: dataset-pdf/1097/images/Figure_20.png
#   inflating: dataset-pdf/1097/images/Figure_4.png
#   inflating: dataset-pdf/107/images/Figure_1.png
#   inflating: dataset-pdf/107/images/Figure_4.png
#   inflating: dataset-pdf/107/images/Table_2.png
#   inflating: dataset-pdf/1097/images/Figure_21.png
#   inflating: dataset-pdf/678/slide.pdf
#   inflating: dataset-pdf/678/input_prompt.txt
#   inflating: dataset-pdf/678/extracted_text.txt
#   inflating: dataset-pdf/678/paper.tei.xml
#   inflating: dataset-pdf/678/figures_and_tables.txt
#   inflating: dataset-pdf/216/images/Figure_4.png
#   inflating: dataset-pdf/107/images/Table_3.png
#   inflating: dataset-pdf/678/slide.md
#   inflating: dataset-pdf/107/images/Table_1.png
#   inflating: dataset-pdf/216/images/Figure_2.png
#   inflating: dataset-pdf/71/figures_and_tables.txt
#   inflating: dataset-pdf/216/images/Figure_3.png
#   inflating: dataset-pdf/216/images/Figure_1.png
#   inflating: dataset-pdf/678/paper.pdf
#   inflating: dataset-pdf/71/slide.md
#   inflating: dataset-pdf/678/810.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/216/images/Figure_5.png
#   inflating: dataset-pdf/678/extracted_text_with_tag.txt
#   inflating: dataset-pdf/71/input_prompt.txt
#   inflating: dataset-pdf/71/81.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/216/images/Table_1.png
#   inflating: dataset-pdf/71/paper.tei.xml
#   inflating: dataset-pdf/404/slide.xml
#   inflating: dataset-pdf/71/slide.pdf
#   inflating: dataset-pdf/404/491.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/71/extracted_text.txt
#   inflating: dataset-pdf/71/slide.xml
#   inflating: dataset-pdf/404/paper.tei.xml
#   inflating: dataset-pdf/71/extracted_text_with_tag.txt
#   inflating: dataset-pdf/71/paper.pdf
#   inflating: dataset-pdf/1097/images/Figure_10.png
#   inflating: dataset-pdf/110/figures_and_tables.txt
#   inflating: dataset-pdf/404/extracted_text_with_tag.txt
#   inflating: dataset-pdf/404/paper.pdf
#   inflating: dataset-pdf/404/slide.md
#   inflating: dataset-pdf/110/input_prompt.txt
#   inflating: dataset-pdf/110/slide.xml
#   inflating: dataset-pdf/404/extracted_text.txt
#   inflating: dataset-pdf/126/images/Figure_6.png
#   inflating: dataset-pdf/404/figures_and_tables.txt
#   inflating: dataset-pdf/110/slide.pdf
#   inflating: dataset-pdf/110/extracted_text_with_tag.txt
#   inflating: dataset-pdf/404/input_prompt.txt
#   inflating: dataset-pdf/110/extracted_text.txt
#   inflating: dataset-pdf/678/images/Figure_9.png
#   inflating: dataset-pdf/110/slide.md
#   inflating: dataset-pdf/678/images/Figure_6.png
#   inflating: dataset-pdf/678/images/Figure_4.png
#   inflating: dataset-pdf/678/images/Figure_12.png
#   inflating: dataset-pdf/678/images/Figure_7.png
#   inflating: dataset-pdf/678/images/Figure_8.png
#   inflating: dataset-pdf/678/images/Figure_3.png
#   inflating: dataset-pdf/110/paper.pdf
#   inflating: dataset-pdf/678/images/Table_1.png
#   inflating: dataset-pdf/678/images/Table_2.png
#   inflating: dataset-pdf/110/126.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/678/images/Figure_5.png
#   inflating: dataset-pdf/678/images/Figure_10.png
#   inflating: dataset-pdf/18/images/Figure_8.png
#   inflating: dataset-pdf/678/images/Figure_1.png
#   inflating: dataset-pdf/18/images/Figure_3.png
#   inflating: dataset-pdf/18/images/Figure_11.png
#   inflating: dataset-pdf/18/images/Figure_4.png
#   inflating: dataset-pdf/218/extracted_text.txt
#   inflating: dataset-pdf/218/slide.md
#   inflating: dataset-pdf/18/images/Figure_1.png
#   inflating: dataset-pdf/18/images/Figure_10.png
#   inflating: dataset-pdf/18/images/Figure_6.png
#   inflating: dataset-pdf/110/paper.tei.xml
#   inflating: dataset-pdf/678/images/Figure_14.png
#   inflating: dataset-pdf/461/figures_and_tables.txt
#   inflating: dataset-pdf/218/paper.pdf
#   inflating: dataset-pdf/218/input_prompt.txt
#   inflating: dataset-pdf/218/paper.tei.xml
#   inflating: dataset-pdf/218/256.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/218/figures_and_tables.txt
#   inflating: dataset-pdf/18/images/Figure_2.png
#   inflating: dataset-pdf/218/slide.pdf
#   inflating: dataset-pdf/461/input_prompt.txt
#   inflating: dataset-pdf/461/561.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/461/paper.pdf
#   inflating: dataset-pdf/461/extracted_text.txt
#   inflating: dataset-pdf/461/slide.md
#   inflating: dataset-pdf/218/slide.xml
#   inflating: dataset-pdf/461/slide.xml
#   inflating: dataset-pdf/461/slide.pdf
#   inflating: dataset-pdf/83/figures_and_tables.txt
#   inflating: dataset-pdf/461/paper.tei.xml
#   inflating: dataset-pdf/461/extracted_text_with_tag.txt
#   inflating: dataset-pdf/83/slide.xml
#   inflating: dataset-pdf/83/slide.md
#   inflating: dataset-pdf/218/extracted_text_with_tag.txt
#   inflating: dataset-pdf/83/paper.tei.xml
#   inflating: dataset-pdf/83/93.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/1073/images/Table_1.png
#   inflating: dataset-pdf/83/extracted_text_with_tag.txt
#   inflating: dataset-pdf/1073/images/Figure_3.png
#   inflating: dataset-pdf/1073/images/Table_2.png
#   inflating: dataset-pdf/1073/images/Figure_9.png
#   inflating: dataset-pdf/83/slide.pdf
#   inflating: dataset-pdf/83/input_prompt.txt
#   inflating: dataset-pdf/1073/images/Figure_13.png
#   inflating: dataset-pdf/83/paper.pdf
#   inflating: dataset-pdf/83/extracted_text.txt
#   inflating: dataset-pdf/1073/images/Figure_12.png
#   inflating: dataset-pdf/1073/images/Figure_2.png
#   inflating: dataset-pdf/1073/images/Figure_11.png
#   inflating: dataset-pdf/1073/images/Figure_1.png
#   inflating: dataset-pdf/1073/images/Figure_10.png
#   inflating: dataset-pdf/1073/images/Figure_16.png
#   inflating: dataset-pdf/1073/images/Figure_15.png
#   inflating: dataset-pdf/1073/images/Figure_14.png
#   inflating: dataset-pdf/1073/images/Figure_5.png
#   inflating: dataset-pdf/1073/images/Figure_8.png
#   inflating: dataset-pdf/529/images/Figure_10.png
#   inflating: dataset-pdf/1073/images/Figure_7.png
#    creating: dataset-pdf/498/images/
#   inflating: dataset-pdf/529/images/Figure_9.png
#   inflating: dataset-pdf/529/images/Figure_4.png
#   inflating: dataset-pdf/312/images/Figure_5.png
#   inflating: dataset-pdf/1073/images/Figure_6.png
#   inflating: dataset-pdf/529/images/Figure_1.png
#   inflating: dataset-pdf/1073/images/Figure_4.png
#   inflating: dataset-pdf/312/images/Figure_4.png
#   inflating: dataset-pdf/529/images/Figure_5.png
#   inflating: dataset-pdf/312/images/Figure_1.png
#   inflating: dataset-pdf/312/images/Figure_3.png
#   inflating: dataset-pdf/529/images/Figure_2.png
#   inflating: dataset-pdf/529/images/Figure_3.png
#   inflating: dataset-pdf/529/images/Figure_6.png
#   inflating: dataset-pdf/312/images/Figure_2.png
#   inflating: dataset-pdf/312/images/Figure_6.png
#   inflating: dataset-pdf/529/images/Figure_8.png
#   inflating: dataset-pdf/85/images/Figure_2.png
#   inflating: dataset-pdf/85/images/Figure_1.png
#   inflating: dataset-pdf/59/slide.md
#   inflating: dataset-pdf/529/images/Figure_7.png
#   inflating: dataset-pdf/678/images/Figure_2.png
#   inflating: dataset-pdf/59/slide.xml
#   inflating: dataset-pdf/59/paper.tei.xml
#   inflating: dataset-pdf/59/figures_and_tables.txt
#   inflating: dataset-pdf/202/images/Figure_3.png
#   inflating: dataset-pdf/59/extracted_text.txt
#   inflating: dataset-pdf/59/input_prompt.txt
#   inflating: dataset-pdf/59/extracted_text_with_tag.txt
#   inflating: dataset-pdf/202/images/Figure_2.png
#   inflating: dataset-pdf/83/images/Table_3.png
#   inflating: dataset-pdf/404/slide.pdf
#   inflating: dataset-pdf/143/images/Figure_10.png
#   inflating: dataset-pdf/202/images/Figure_1.png
#   inflating: dataset-pdf/83/images/Table_1.png
#   inflating: dataset-pdf/202/images/Figure_4.png
#   inflating: dataset-pdf/59/paper.pdf
#   inflating: dataset-pdf/202/images/Figure_5.png
#   inflating: dataset-pdf/83/images/Table_2.png
#   inflating: dataset-pdf/0/extracted_text.txt
#   inflating: dataset-pdf/0/slide.xml
#   inflating: dataset-pdf/0/input_prompt.txt
#   inflating: dataset-pdf/197/images/Table_1.png
#   inflating: dataset-pdf/197/images/Table_2.png
#   inflating: dataset-pdf/0/figures_and_tables.txt
#   inflating: dataset-pdf/197/images/Figure_2.png
#   inflating: dataset-pdf/246/images/Figure_2.png
#   inflating: dataset-pdf/197/images/Figure_1.png
#   inflating: dataset-pdf/246/images/Figure_4.png
#   inflating: dataset-pdf/246/images/Figure_5.png
#   inflating: dataset-pdf/0/extracted_text_with_tag.txt
#   inflating: dataset-pdf/246/images/Figure_3.png
#   inflating: dataset-pdf/592/images/Figure_12.png
#   inflating: dataset-pdf/59/slide.pdf
#   inflating: dataset-pdf/0/paper.tei.xml
#   inflating: dataset-pdf/246/images/Figure_7.png
#   inflating: dataset-pdf/0/slide.md
#   inflating: dataset-pdf/592/images/Figure_4.png
#   inflating: dataset-pdf/0/1.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/246/images/Figure_6.png
#   inflating: dataset-pdf/246/images/Figure_1.png
#   inflating: dataset-pdf/0/paper.pdf
#   inflating: dataset-pdf/292/342.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/292/slide.xml
#   inflating: dataset-pdf/193/images/Figure_1.png
#   inflating: dataset-pdf/0/slide.pdf
#   inflating: dataset-pdf/292/figures_and_tables.txt
#   inflating: dataset-pdf/193/images/Figure_2.png
#   inflating: dataset-pdf/59/68.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/292/input_prompt.txt
#   inflating: dataset-pdf/292/slide.pdf
#   inflating: dataset-pdf/292/extracted_text.txt
#   inflating: dataset-pdf/193/images/Figure_3.png
#   inflating: dataset-pdf/193/images/Figure_4.png
#   inflating: dataset-pdf/544/images/Figure_7.png
#   inflating: dataset-pdf/544/images/Table_4.png
#   inflating: dataset-pdf/544/images/Table_3.png
#   inflating: dataset-pdf/292/slide.md
#   inflating: dataset-pdf/544/images/Figure_5.png
#   inflating: dataset-pdf/544/images/Figure_12.png
#   inflating: dataset-pdf/544/images/Table_5.png
#   inflating: dataset-pdf/544/images/Figure_6.png
#   inflating: dataset-pdf/292/paper.pdf
#   inflating: dataset-pdf/292/paper.tei.xml
#   inflating: dataset-pdf/292/extracted_text_with_tag.txt
#   inflating: dataset-pdf/544/images/Figure_2.png
#   inflating: dataset-pdf/544/images/Figure_1.png
#   inflating: dataset-pdf/544/images/Table_6.png
#   inflating: dataset-pdf/544/images/Figure_3.png
#   inflating: dataset-pdf/544/images/Figure_8.png
#   inflating: dataset-pdf/544/images/Figure_11.png
#   inflating: dataset-pdf/544/images/Figure_9.png
#   inflating: dataset-pdf/544/images/Figure_13.png
#   inflating: dataset-pdf/930/images/Table_6.png
#    creating: dataset-pdf/461/images/
#   inflating: dataset-pdf/930/images/Figure_5.png
#   inflating: dataset-pdf/544/images/Table_1.png
#   inflating: dataset-pdf/544/images/Table_2.png
#   inflating: dataset-pdf/930/images/Figure_7.png
#   inflating: dataset-pdf/930/images/Figure_4.png
#   inflating: dataset-pdf/292/images/Table_1.png
#   inflating: dataset-pdf/930/images/Table_3.png
#   inflating: dataset-pdf/292/images/Figure_5.png
#   inflating: dataset-pdf/930/images/Figure_1.png
#   inflating: dataset-pdf/292/images/Figure_2.png
#   inflating: dataset-pdf/930/images/Figure_3.png
#   inflating: dataset-pdf/292/images/Figure_7.png
#   inflating: dataset-pdf/930/images/Table_5.png
#   inflating: dataset-pdf/930/images/Figure_2.png
#   inflating: dataset-pdf/930/images/Table_4.png
#   inflating: dataset-pdf/930/images/Table_2.png
#   inflating: dataset-pdf/292/images/Figure_3.png
#   inflating: dataset-pdf/292/images/Figure_4.png
#   inflating: dataset-pdf/930/images/Figure_8.png
#   inflating: dataset-pdf/930/images/Table_1.png
#   inflating: dataset-pdf/930/images/Figure_6.png
#   inflating: dataset-pdf/292/images/Figure_6.png
#   inflating: dataset-pdf/930/images/Table_7.png
#   inflating: dataset-pdf/592/images/Figure_6.png
#   inflating: dataset-pdf/404/images/Figure_9.png
#   inflating: dataset-pdf/0/images/Figure_3.png
#   inflating: dataset-pdf/0/images/Figure_1.png
#   inflating: dataset-pdf/404/images/Figure_1.png
#   inflating: dataset-pdf/404/images/Figure_4.png
#   inflating: dataset-pdf/930/images/Table_8.png
#   inflating: dataset-pdf/292/images/Figure_1.png
#   inflating: dataset-pdf/404/images/Figure_6.png
#   inflating: dataset-pdf/404/images/Figure_5.png
#   inflating: dataset-pdf/292/images/Figure_8.png
#   inflating: dataset-pdf/404/images/Figure_2.png
#   inflating: dataset-pdf/404/images/Figure_8.png
#   inflating: dataset-pdf/794/slide.md
#   inflating: dataset-pdf/794/slide.xml
#   inflating: dataset-pdf/794/slide.pdf
#   inflating: dataset-pdf/794/948.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/794/paper.tei.xml
#   inflating: dataset-pdf/673/images/Figure_7.png
#   inflating: dataset-pdf/673/images/Figure_10.png
#   inflating: dataset-pdf/794/extracted_text.txt
#   inflating: dataset-pdf/794/extracted_text_with_tag.txt
#   inflating: dataset-pdf/673/images/Figure_4.png
#    creating: dataset-pdf/71/images/
#   inflating: dataset-pdf/673/images/Figure_1.png
#   inflating: dataset-pdf/794/figures_and_tables.txt
#   inflating: dataset-pdf/404/images/Figure_3.png
#   inflating: dataset-pdf/794/paper.pdf
#   inflating: dataset-pdf/673/images/Table_2.png
#   inflating: dataset-pdf/673/images/Figure_5.png
#   inflating: dataset-pdf/59/images/Figure_2.png
#   inflating: dataset-pdf/673/images/Figure_9.png
#   inflating: dataset-pdf/673/images/Figure_2.png
#   inflating: dataset-pdf/673/images/Figure_3.png
#   inflating: dataset-pdf/673/images/Figure_8.png
#   inflating: dataset-pdf/673/images/Figure_6.png
#   inflating: dataset-pdf/794/input_prompt.txt
#   inflating: dataset-pdf/673/images/Table_1.png
#   inflating: dataset-pdf/794/images/Figure_7.png
#   inflating: dataset-pdf/794/images/Figure_16.png
#   inflating: dataset-pdf/673/images/Figure_11.png
#   inflating: dataset-pdf/673/images/Table_3.png
#   inflating: dataset-pdf/794/images/Figure_9.png
#   inflating: dataset-pdf/218/images/Figure_1.png
#   inflating: dataset-pdf/794/images/Figure_11.png
#   inflating: dataset-pdf/794/images/Figure_2.png
#   inflating: dataset-pdf/794/images/Figure_13.png
#   inflating: dataset-pdf/794/images/Figure_6.png
#   inflating: dataset-pdf/794/images/Figure_14.png
#   inflating: dataset-pdf/794/images/Figure_1.png
#   inflating: dataset-pdf/794/images/Figure_10.png
#   inflating: dataset-pdf/794/images/Table_1.png
#   inflating: dataset-pdf/794/images/Figure_5.png
#   inflating: dataset-pdf/794/images/Figure_15.png
#   inflating: dataset-pdf/794/images/Figure_3.png
#   inflating: dataset-pdf/794/images/Figure_12.png
#   inflating: dataset-pdf/794/images/Figure_8.png
#   inflating: dataset-pdf/70/input_prompt.txt
#   inflating: dataset-pdf/70/figures_and_tables.txt
#   inflating: dataset-pdf/70/slide.pdf
#   inflating: dataset-pdf/70/slide.xml
#   inflating: dataset-pdf/372/images/Figure_4.png
#   inflating: dataset-pdf/70/80.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/70/paper.tei.xml
#   inflating: dataset-pdf/372/images/Figure_1.png
#   inflating: dataset-pdf/70/paper.pdf
#   inflating: dataset-pdf/372/images/Figure_9.png
#   inflating: dataset-pdf/372/images/Table_1.png
#   inflating: dataset-pdf/70/extracted_text_with_tag.txt
#   inflating: dataset-pdf/372/images/Figure_10.png
#   inflating: dataset-pdf/70/extracted_text.txt
#   inflating: dataset-pdf/372/images/Figure_8.png
#   inflating: dataset-pdf/372/images/Figure_12.png
#   inflating: dataset-pdf/1083/images/Table_7.png
#   inflating: dataset-pdf/372/images/Figure_11.png
#   inflating: dataset-pdf/70/slide.md
#   inflating: dataset-pdf/372/images/Figure_7.png
#   inflating: dataset-pdf/372/images/Table_2.png
#   inflating: dataset-pdf/1083/images/Figure_2.png
#   inflating: dataset-pdf/372/images/Figure_6.png
#   inflating: dataset-pdf/372/images/Figure_5.png
#   inflating: dataset-pdf/372/images/Figure_2.png
#   inflating: dataset-pdf/1083/images/Table_4.png
#   inflating: dataset-pdf/1083/images/Table_5.png
#   inflating: dataset-pdf/372/images/Figure_3.png
#   inflating: dataset-pdf/1083/images/Table_10.png
#   inflating: dataset-pdf/1083/images/Table_2.png
#   inflating: dataset-pdf/1083/images/Table_3.png
#   inflating: dataset-pdf/1083/images/Figure_3.png
#   inflating: dataset-pdf/1083/images/Figure_5.png
#   inflating: dataset-pdf/1083/images/Table_1.png
#   inflating: dataset-pdf/1083/images/Figure_1.png
#   inflating: dataset-pdf/1083/images/Table_9.png
#   inflating: dataset-pdf/446/images/Figure_2.png
#   inflating: dataset-pdf/446/images/Table_3.png
#   inflating: dataset-pdf/446/images/Figure_1.png
#   inflating: dataset-pdf/446/images/Figure_5.png
#   inflating: dataset-pdf/70/images/Figure_2.png
#   inflating: dataset-pdf/446/images/Table_2.png
#   inflating: dataset-pdf/1083/images/Figure_4.png
#   inflating: dataset-pdf/1083/images/Figure_6.png
#   inflating: dataset-pdf/70/images/Table_1.png
#   inflating: dataset-pdf/70/images/Figure_3.png
#   inflating: dataset-pdf/446/images/Table_1.png
#   inflating: dataset-pdf/446/images/Figure_6.png
#   inflating: dataset-pdf/446/images/Figure_7.png
#   inflating: dataset-pdf/592/images/Figure_10.png
#   inflating: dataset-pdf/70/images/Figure_1.png
#   inflating: dataset-pdf/1083/images/Table_6.png
#   inflating: dataset-pdf/446/images/Figure_3.png
#   inflating: dataset-pdf/446/images/Figure_4.png
#   inflating: dataset-pdf/1083/images/Table_8.png
#   inflating: dataset-pdf/70/images/Table_2.png
#   inflating: dataset-pdf/794/images/Figure_4.png
#   inflating: dataset-pdf/453/input_prompt.txt
#   inflating: dataset-pdf/366/441.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/366/slide.pdf
#   inflating: dataset-pdf/366/paper.pdf
#   inflating: dataset-pdf/366/extracted_text_with_tag.txt
#   inflating: dataset-pdf/366/slide.xml
#   inflating: dataset-pdf/366/figures_and_tables.txt
#   inflating: dataset-pdf/366/slide.md
#   inflating: dataset-pdf/366/input_prompt.txt
#   inflating: dataset-pdf/142/images/Figure_17.png
#   inflating: dataset-pdf/142/images/Table_4.png
#   inflating: dataset-pdf/142/images/Table_3.png
#   inflating: dataset-pdf/446/images/Table_4.png
#   inflating: dataset-pdf/366/extracted_text.txt
#   inflating: dataset-pdf/366/paper.tei.xml
#   inflating: dataset-pdf/142/images/Figure_15.png
#   inflating: dataset-pdf/142/images/Figure_4.png
#   inflating: dataset-pdf/142/images/Figure_9.png
#   inflating: dataset-pdf/142/images/Table_5.png
#   inflating: dataset-pdf/142/images/Figure_1.png
#   inflating: dataset-pdf/142/images/Figure_18.png
#   inflating: dataset-pdf/142/images/Figure_14.png
#   inflating: dataset-pdf/142/images/Table_6.png
#   inflating: dataset-pdf/366/images/Figure_1.png
#   inflating: dataset-pdf/142/images/Figure_8.png
#   inflating: dataset-pdf/142/images/Table_7.png
#   inflating: dataset-pdf/142/images/Figure_7.png
#   inflating: dataset-pdf/873/slide.xml
#   inflating: dataset-pdf/142/images/Figure_16.png
#   inflating: dataset-pdf/829/extracted_text.txt
#   inflating: dataset-pdf/142/images/Figure_13.png
#   inflating: dataset-pdf/142/images/Figure_3.png
#   inflating: dataset-pdf/142/images/Table_8.png
#   inflating: dataset-pdf/453/slide.xml
#   inflating: dataset-pdf/716/extracted_text_with_tag.txt
#   inflating: dataset-pdf/909/extracted_text.txt
#   inflating: dataset-pdf/306/362.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/809/965.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/45/slide.md
#   inflating: dataset-pdf/339/slide.xml
#   inflating: dataset-pdf/45/52.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/329/images/Table_2.png
#   inflating: dataset-pdf/45/paper.tei.xml
#   inflating: dataset-pdf/45/extracted_text.txt
#   inflating: dataset-pdf/45/input_prompt.txt
#   inflating: dataset-pdf/329/images/Figure_3.png
#   inflating: dataset-pdf/45/slide.xml
#   inflating: dataset-pdf/329/images/Table_1.png
#   inflating: dataset-pdf/329/images/Figure_1.png
#   inflating: dataset-pdf/182/slide.xml
#   inflating: dataset-pdf/329/images/Figure_4.png
#   inflating: dataset-pdf/182/paper.tei.xml
#   inflating: dataset-pdf/182/208.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/45/extracted_text_with_tag.txt
#   inflating: dataset-pdf/162/slide.xml
#   inflating: dataset-pdf/45/figures_and_tables.txt
#   inflating: dataset-pdf/182/input_prompt.txt
#   inflating: dataset-pdf/329/images/Figure_2.png
#   inflating: dataset-pdf/182/extracted_text.txt
#   inflating: dataset-pdf/162/extracted_text_with_tag.txt
#   inflating: dataset-pdf/45/paper.pdf
#   inflating: dataset-pdf/182/slide.md
#   inflating: dataset-pdf/1094/images/Figure_2.png
#   inflating: dataset-pdf/162/paper.tei.xml
#   inflating: dataset-pdf/182/figures_and_tables.txt
#   inflating: dataset-pdf/182/extracted_text_with_tag.txt
#   inflating: dataset-pdf/17/figures_and_tables.txt
#   inflating: dataset-pdf/162/186.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/1094/images/Figure_1.png
#   inflating: dataset-pdf/162/extracted_text.txt
#    creating: dataset-pdf/410/images/
#   inflating: dataset-pdf/17/slide.xml
#   inflating: dataset-pdf/182/paper.pdf
#   inflating: dataset-pdf/17/input_prompt.txt
#   inflating: dataset-pdf/17/18.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/162/paper.pdf
#   inflating: dataset-pdf/17/extracted_text_with_tag.txt
#   inflating: dataset-pdf/17/slide.md
#   inflating: dataset-pdf/228/slide.xml
#   inflating: dataset-pdf/110/images/Figure_1.png
#   inflating: dataset-pdf/228/figures_and_tables.txt
#   inflating: dataset-pdf/228/266.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/162/slide.pdf
#   inflating: dataset-pdf/45/slide.pdf
#   inflating: dataset-pdf/182/slide.pdf
#   inflating: dataset-pdf/228/slide.md
#   inflating: dataset-pdf/17/slide.pdf
#   inflating: dataset-pdf/228/slide.pdf
#   inflating: dataset-pdf/228/extracted_text_with_tag.txt
#   inflating: dataset-pdf/17/extracted_text.txt
#   inflating: dataset-pdf/17/images/Figure_2.png
#   inflating: dataset-pdf/17/paper.tei.xml
#   inflating: dataset-pdf/228/paper.tei.xml
#   inflating: dataset-pdf/162/figures_and_tables.txt
#   inflating: dataset-pdf/228/extracted_text.txt
#   inflating: dataset-pdf/17/images/Figure_3.png
# ...
#   inflating: dataset-pdf/767/input_prompt.txt
#   inflating: dataset-pdf/767/paper.tei.xml
#   inflating: dataset-pdf/874/images/Table_4.png
#   inflating: dataset-pdf/767/916.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/874/images/Figure_20.png
#   inflating: dataset-pdf/874/images/Table_3.png
#   inflating: dataset-pdf/874/images/Figure_4.png
#   inflating: dataset-pdf/210/slide.pdf
#   inflating: dataset-pdf/767/slide.xml
#   inflating: dataset-pdf/874/images/Table_2.png
#   inflating: dataset-pdf/1031/slide.pdf
#   inflating: dataset-pdf/874/images/Figure_7.png
#   inflating: dataset-pdf/874/images/Figure_16.png
#   inflating: dataset-pdf/874/images/Figure_11.png
#   inflating: dataset-pdf/874/images/Figure_6.png
#   inflating: dataset-pdf/874/images/Figure_17.png
#   inflating: dataset-pdf/767/slide.pdf
#   inflating: dataset-pdf/874/images/Figure_22.png
#   inflating: dataset-pdf/874/images/Figure_12.png
#   inflating: dataset-pdf/874/images/Figure_19.png
#   inflating: dataset-pdf/868/slide.xml
#   inflating: dataset-pdf/868/1047.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/874/images/Figure_1.png
#   inflating: dataset-pdf/874/images/Figure_10.png
#   inflating: dataset-pdf/868/figures_and_tables.txt
#   inflating: dataset-pdf/874/images/Figure_14.png
#   inflating: dataset-pdf/874/images/Figure_21.png
#   inflating: dataset-pdf/874/images/Figure_8.png
#   inflating: dataset-pdf/868/images/Figure_5.png
#   inflating: dataset-pdf/874/images/Figure_3.png
#   inflating: dataset-pdf/868/images/Figure_12.png
#   inflating: dataset-pdf/868/images/Figure_3.png
#   inflating: dataset-pdf/868/images/Figure_4.png
#   inflating: dataset-pdf/868/extracted_text.txt
#   inflating: dataset-pdf/868/input_prompt.txt
#   inflating: dataset-pdf/868/images/Figure_2.png
#   inflating: dataset-pdf/868/images/Table_2.png
#   inflating: dataset-pdf/868/images/Figure_1.png
#   inflating: dataset-pdf/868/images/Figure_6.png
#   inflating: dataset-pdf/868/images/Figure_11.png
#   inflating: dataset-pdf/868/paper.pdf
#   inflating: dataset-pdf/868/paper.tei.xml
#   inflating: dataset-pdf/868/slide.pdf
#   inflating: dataset-pdf/868/slide.md
#   inflating: dataset-pdf/868/images/Table_1.png
#   inflating: dataset-pdf/868/images/Figure_9.png
#   inflating: dataset-pdf/874/images/Figure_18.png
#   inflating: dataset-pdf/868/extracted_text_with_tag.txt
#   inflating: dataset-pdf/868/images/Figure_8.png
#   inflating: dataset-pdf/868/images/Figure_7.png
#   inflating: dataset-pdf/767/images/Figure_3.png
#   inflating: dataset-pdf/767/images/Figure_1.png
#   inflating: dataset-pdf/767/images/Figure_8.png
#   inflating: dataset-pdf/767/images/Figure_4.png
#   inflating: dataset-pdf/767/images/Figure_2.png
#   inflating: dataset-pdf/868/images/Figure_10.png
#   inflating: dataset-pdf/700/figures_and_tables.txt
#   inflating: dataset-pdf/767/images/Figure_5.png
#   inflating: dataset-pdf/874/images/Figure_15.png
#   inflating: dataset-pdf/874/images/Figure_13.png
#   inflating: dataset-pdf/210/slide.xml
#   inflating: dataset-pdf/767/images/Figure_7.png
#   inflating: dataset-pdf/1031/slide.xml
#   inflating: dataset-pdf/239/extracted_text_with_tag.txt
#   inflating: dataset-pdf/99/112.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/1031/1245.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/700/839.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/99/slide.md
#   inflating: dataset-pdf/158/paper.pdf
#   inflating: dataset-pdf/692/slide.xml
#   inflating: dataset-pdf/967/figures_and_tables.txt
#   inflating: dataset-pdf/1031/input_prompt.txt
#   inflating: dataset-pdf/210/246.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/1031/paper.tei.xml
#   inflating: dataset-pdf/99/figures_and_tables.txt
#   inflating: dataset-pdf/158/figures_and_tables.txt
#   inflating: dataset-pdf/700/slide.md
#   inflating: dataset-pdf/700/extracted_text_with_tag.txt
#   inflating: dataset-pdf/1031/paper.pdf
#   inflating: dataset-pdf/1031/slide.md
#   inflating: dataset-pdf/692/input_prompt.txt
#   inflating: dataset-pdf/967/paper.tei.xml
#   inflating: dataset-pdf/1031/extracted_text.txt
#   inflating: dataset-pdf/1031/extracted_text_with_tag.txt
#   inflating: dataset-pdf/994/images/Figure_1.png
#   inflating: dataset-pdf/239/input_prompt.txt
#   inflating: dataset-pdf/692/slide.pdf
#   inflating: dataset-pdf/951/slide.md
#   inflating: dataset-pdf/951/slide.xml
#   inflating: dataset-pdf/158/extracted_text_with_tag.txt
#   inflating: dataset-pdf/210/paper.tei.xml
#   inflating: dataset-pdf/951/slide.pdf
#   inflating: dataset-pdf/239/paper.pdf
#   inflating: dataset-pdf/951/extracted_text.txt
#   inflating: dataset-pdf/951/extracted_text_with_tag.txt
#   inflating: dataset-pdf/951/images/Figure_2.png
#   inflating: dataset-pdf/951/figures_and_tables.txt
#   inflating: dataset-pdf/951/input_prompt.txt
#   inflating: dataset-pdf/700/extracted_text.txt
#   inflating: dataset-pdf/210/extracted_text.txt
#   inflating: dataset-pdf/951/images/Table_1.png
#   inflating: dataset-pdf/951/images/Figure_1.png
#   inflating: dataset-pdf/951/1148.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/951/images/Table_2.png
#   inflating: dataset-pdf/951/images/Figure_3.png
#   inflating: dataset-pdf/951/paper.tei.xml
#   inflating: dataset-pdf/967/input_prompt.txt
#   inflating: dataset-pdf/149/slide.xml
#   inflating: dataset-pdf/99/input_prompt.txt
#   inflating: dataset-pdf/149/input_prompt.txt
#   inflating: dataset-pdf/692/figures_and_tables.txt
#   inflating: dataset-pdf/692/extracted_text_with_tag.txt
#   inflating: dataset-pdf/99/extracted_text_with_tag.txt
#   inflating: dataset-pdf/692/extracted_text.txt
#   inflating: dataset-pdf/210/figures_and_tables.txt
#   inflating: dataset-pdf/158/extracted_text.txt
#   inflating: dataset-pdf/149/slide.pdf
#   inflating: dataset-pdf/692/paper.tei.xml
#   inflating: dataset-pdf/692/slide.md
#   inflating: dataset-pdf/239/figures_and_tables.txt
#   inflating: dataset-pdf/864/input_prompt.txt
#   inflating: dataset-pdf/692/831.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/210/extracted_text_with_tag.txt
#   inflating: dataset-pdf/231/images/Figure_3.png
#   inflating: dataset-pdf/210/input_prompt.txt
#   inflating: dataset-pdf/951/paper.pdf
#   inflating: dataset-pdf/99/paper.tei.xml
#   inflating: dataset-pdf/210/slide.md
#   inflating: dataset-pdf/682/slide.xml
#   inflating: dataset-pdf/149/figures_and_tables.txt
#   inflating: dataset-pdf/312/figures_and_tables.txt
#   inflating: dataset-pdf/312/slide.xml
#   inflating: dataset-pdf/99/paper.pdf
#   inflating: dataset-pdf/158/181.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/682/818.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/864/slide.md
#   inflating: dataset-pdf/210/paper.pdf
#   inflating: dataset-pdf/158/slide.md
#   inflating: dataset-pdf/682/slide.pdf
#   inflating: dataset-pdf/239/paper.tei.xml
#   inflating: dataset-pdf/965/images/Figure_8.png
#   inflating: dataset-pdf/864/slide.pdf
#   inflating: dataset-pdf/971/slide.xml
#   inflating: dataset-pdf/864/slide.xml
#   inflating: dataset-pdf/312/slide.md
#   inflating: dataset-pdf/149/paper.tei.xml
#   inflating: dataset-pdf/312/input_prompt.txt
#   inflating: dataset-pdf/312/slide.pdf
#   inflating: dataset-pdf/864/figures_and_tables.txt
#   inflating: dataset-pdf/158/paper.tei.xml
#   inflating: dataset-pdf/312/extracted_text_with_tag.txt
#   inflating: dataset-pdf/239/slide.xml
#   inflating: dataset-pdf/231/images/Figure_2.png
#   inflating: dataset-pdf/231/images/Figure_5.png
#   inflating: dataset-pdf/971/figures_and_tables.txt
#   inflating: dataset-pdf/682/figures_and_tables.txt
#   inflating: dataset-pdf/864/1037.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/971/paper.pdf
#   inflating: dataset-pdf/149/slide.md
#   inflating: dataset-pdf/971/1174.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/312/extracted_text.txt
#   inflating: dataset-pdf/682/extracted_text.txt
#   inflating: dataset-pdf/312/paper.pdf
#   inflating: dataset-pdf/239/slide.md
#   inflating: dataset-pdf/231/images/Table_1.png
#   inflating: dataset-pdf/312/372.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/312/paper.tei.xml
#   inflating: dataset-pdf/971/slide.pdf
#   inflating: dataset-pdf/149/extracted_text.txt
#   inflating: dataset-pdf/864/extracted_text_with_tag.txt
#   inflating: dataset-pdf/724/images/Figure_2.png
#   inflating: dataset-pdf/231/images/Figure_4.png
#   inflating: dataset-pdf/971/paper.tei.xml
#   inflating: dataset-pdf/130/slide.pdf
#   inflating: dataset-pdf/682/extracted_text_with_tag.txt
#   inflating: dataset-pdf/682/paper.pdf
#   inflating: dataset-pdf/130/slide.md
#   inflating: dataset-pdf/130/input_prompt.txt
#   inflating: dataset-pdf/149/extracted_text_with_tag.txt
#   inflating: dataset-pdf/130/slide.xml
#   inflating: dataset-pdf/149/172.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/971/extracted_text_with_tag.txt
#   inflating: dataset-pdf/971/slide.md
#   inflating: dataset-pdf/971/input_prompt.txt
#   inflating: dataset-pdf/864/paper.tei.xml
#   inflating: dataset-pdf/130/extracted_text_with_tag.txt
#   inflating: dataset-pdf/724/images/Figure_1.png
#   inflating: dataset-pdf/682/slide.md
#   inflating: dataset-pdf/682/input_prompt.txt
#   inflating: dataset-pdf/971/extracted_text.txt
#   inflating: dataset-pdf/682/paper.tei.xml
#   inflating: dataset-pdf/864/extracted_text.txt
#   inflating: dataset-pdf/231/images/Figure_1.png
#   inflating: dataset-pdf/130/paper.tei.xml
#   inflating: dataset-pdf/724/images/Figure_5.png
#   inflating: dataset-pdf/130/figures_and_tables.txt
#   inflating: dataset-pdf/982/slide.md
#   inflating: dataset-pdf/677/slide.xml
#   inflating: dataset-pdf/982/extracted_text.txt
#   inflating: dataset-pdf/207/slide.xml
#   inflating: dataset-pdf/724/images/Figure_6.png
#   inflating: dataset-pdf/982/figures_and_tables.txt
#   inflating: dataset-pdf/130/extracted_text.txt
#   inflating: dataset-pdf/677/input_prompt.txt
#   inflating: dataset-pdf/864/paper.pdf
#   inflating: dataset-pdf/252/slide.xml
#   inflating: dataset-pdf/724/images/Figure_4.png
#   inflating: dataset-pdf/130/148.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/982/paper.tei.xml
#   inflating: dataset-pdf/982/slide.xml
#   inflating: dataset-pdf/982/slide.pdf
#   inflating: dataset-pdf/207/238.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/207/extracted_text.txt
#   inflating: dataset-pdf/149/paper.pdf
#   inflating: dataset-pdf/677/809.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/252/paper.tei.xml
#   inflating: dataset-pdf/982/1193.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/692/paper.pdf
#   inflating: dataset-pdf/207/figures_and_tables.txt
#   inflating: dataset-pdf/207/paper.tei.xml
#   inflating: dataset-pdf/252/extracted_text_with_tag.txt
#   inflating: dataset-pdf/982/input_prompt.txt
#   inflating: dataset-pdf/677/slide.md
#   inflating: dataset-pdf/252/slide.pdf
#   inflating: dataset-pdf/207/extracted_text_with_tag.txt
#   inflating: dataset-pdf/252/extracted_text.txt
#   inflating: dataset-pdf/252/figures_and_tables.txt
#   inflating: dataset-pdf/165/slide.pdf
#   inflating: dataset-pdf/207/slide.md
#   inflating: dataset-pdf/677/figures_and_tables.txt
#   inflating: dataset-pdf/677/slide.pdf
#   inflating: dataset-pdf/130/paper.pdf
#   inflating: dataset-pdf/252/295.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/252/input_prompt.txt
#   inflating: dataset-pdf/207/input_prompt.txt
#   inflating: dataset-pdf/128/input_prompt.txt
#   inflating: dataset-pdf/677/paper.tei.xml
#   inflating: dataset-pdf/165/input_prompt.txt
#   inflating: dataset-pdf/252/slide.md
#   inflating: dataset-pdf/677/extracted_text.txt
#   inflating: dataset-pdf/982/extracted_text_with_tag.txt
#   inflating: dataset-pdf/982/paper.pdf
#   inflating: dataset-pdf/677/extracted_text_with_tag.txt
#   inflating: dataset-pdf/165/paper.tei.xml
#   inflating: dataset-pdf/165/slide.xml
#   inflating: dataset-pdf/165/figures_and_tables.txt
#   inflating: dataset-pdf/128/extracted_text_with_tag.txt
#   inflating: dataset-pdf/165/extracted_text_with_tag.txt
#   inflating: dataset-pdf/165/extracted_text.txt
#   inflating: dataset-pdf/165/slide.md
#   inflating: dataset-pdf/207/paper.pdf
#   inflating: dataset-pdf/165/189.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/128/slide.xml
#   inflating: dataset-pdf/165/paper.pdf
#   inflating: dataset-pdf/270/slide.xml
#   inflating: dataset-pdf/270/figures_and_tables.txt
#   inflating: dataset-pdf/128/slide.md
#   inflating: dataset-pdf/270/input_prompt.txt
#   inflating: dataset-pdf/128/figures_and_tables.txt
#   inflating: dataset-pdf/128/paper.tei.xml
#   inflating: dataset-pdf/270/extracted_text.txt
#   inflating: dataset-pdf/128/extracted_text.txt
#   inflating: dataset-pdf/207/slide.pdf
#   inflating: dataset-pdf/270/slide.md
#   inflating: dataset-pdf/259/slide.xml
#   inflating: dataset-pdf/270/extracted_text_with_tag.txt
#   inflating: dataset-pdf/677/paper.pdf
#   inflating: dataset-pdf/128/146.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/270/317.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/252/paper.pdf
#   inflating: dataset-pdf/259/input_prompt.txt
#   inflating: dataset-pdf/270/paper.tei.xml
#   inflating: dataset-pdf/259/paper.tei.xml
#   inflating: dataset-pdf/259/figures_and_tables.txt
#   inflating: dataset-pdf/259/slide.md
#   inflating: dataset-pdf/259/extracted_text.txt
#   inflating: dataset-pdf/128/paper.pdf
#   inflating: dataset-pdf/259/extracted_text_with_tag.txt
#   inflating: dataset-pdf/259/305.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/446/slide.pdf
#   inflating: dataset-pdf/446/slide.md
#   inflating: dataset-pdf/446/546.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/446/extracted_text.txt
#   inflating: dataset-pdf/446/paper.tei.xml
#   inflating: dataset-pdf/446/input_prompt.txt
#   inflating: dataset-pdf/446/slide.xml
#   inflating: dataset-pdf/259/paper.pdf
#   inflating: dataset-pdf/731/images/Figure_3.png
#   inflating: dataset-pdf/446/paper.pdf
#   inflating: dataset-pdf/446/extracted_text_with_tag.txt
#   inflating: dataset-pdf/446/figures_and_tables.txt
#   inflating: dataset-pdf/731/images/Figure_2.png
#   inflating: dataset-pdf/731/images/Figure_1.png
#   inflating: dataset-pdf/128/slide.pdf
#   inflating: dataset-pdf/270/paper.pdf
#   inflating: dataset-pdf/797/images/Figure_6.png
#   inflating: dataset-pdf/797/images/Figure_2.png
#   inflating: dataset-pdf/797/images/Figure_1.png
#   inflating: dataset-pdf/797/images/Figure_5.png
#   inflating: dataset-pdf/270/slide.pdf
#   inflating: dataset-pdf/797/images/Figure_4.png
#   inflating: dataset-pdf/797/images/Figure_3.png
#   inflating: dataset-pdf/259/slide.pdf
#   inflating: dataset-pdf/957/slide.xml
#   inflating: dataset-pdf/957/extracted_text_with_tag.txt
#   inflating: dataset-pdf/957/input_prompt.txt
#   inflating: dataset-pdf/957/1154.windowed_summarunner_scores.txt
#   inflating: dataset-pdf/957/figures_and_tables.txt
#   inflating: dataset-pdf/957/images/Figure_2.png
#   inflating: dataset-pdf/957/images/Figure_1.png
#   inflating: dataset-pdf/957/images/Figure_3.png
#   inflating: dataset-pdf/957/extracted_text.txt
#   inflating: dataset-pdf/957/images/Figure_4.png
#   inflating: dataset-pdf/957/paper.tei.xml
#   inflating: dataset-pdf/957/slide.md
#   inflating: dataset-pdf/957/paper.pdf
#   inflating: dataset-pdf/957/slide.pdf
#   inflating: dataset-pdf/696/images/Figure_2.png
#   inflating: dataset-pdf/696/images/Figure_3.png
#   inflating: dataset-pdf/696/images/Figure_1.png
#   inflating: dataset-pdf/696/images/Figure_4.png
#   inflating: dataset-pdf/1064/images/Table_1.png
#   inflating: dataset-pdf/1064/images/Figure_2.png
#   inflating: dataset-pdf/1064/images/Figure_1.png

# %%
from pathlib import Path
dataset_dir = Path("/content/dataset-pdf")
dataset_dir = sorted(list(dataset_dir.glob("*")), key = lambda x: int(x.name))
# select first 1001 as train left over is test
train_dataset = dataset_dir[:1001]
test_dataset = dataset_dir[1001:]
assert len(train_dataset) == 1001
assert len(test_dataset) == 100
for train_path in train_dataset:
  assert int(train_path.name) < 1001, f"Expect train dataset to be 0-1000 but got {train_path.name}"
for test_path in test_dataset:
  assert int(test_path.name) >= 1001, f"Expect test dataset to be 1001-1100 but got {test_path.name}"

# %%
def get_clean_slide(slide_md_text):
    instruction = f"""FROM:
{slide_md_text}
You will have to cleanup slide text above to easier to understand. If you saw duplicate slide you will have to remove it too.Each slide should cover a complete topic or subtopic, not incremental additions.
For example, if a topic like "Introduction" has several bullet points, combine them into one slide titled "Introduction", rather than creating separate slides for each point.
Keep slide titles concise and avoid repeating titles across multiple slides. You will have to output slide text with ```markdown ``` format. do not include unnecessary text such as Okay. you will have to adjust slide text According to slidev or https://github.com/slidevjs/slidev"""
    return generate_content_with_rate_limit(instruction)

# %%
from tqdm import tqdm
import time
for path in tqdm(train_dataset[105:]):
  unclean_slide_markdown_path = path / "slide.md"
  with open(unclean_slide_markdown_path, "r") as f:
    slide_md_text = f.read()
  slide_md_text = slide_md_text
  try:
    clean_slide_md_text = remove_markdown_tag(get_clean_slide(slide_md_text))
    with open(unclean_slide_markdown_path, "w") as f:
        f.write(clean_slide_md_text)
    time.sleep(4)
  except Exception as e:
    print(e)
    time.sleep(4)
    continue
# Out:
#   0%|          | 0/896 [00:00<?, ?it/s]
# Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 4. Meaning that the model was reciting from copyrighted material.
#  62%|██████▏   | 553/896 [2:14:06<1:13:08, 12.79s/it]
# Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 4. Meaning that the model was reciting from copyrighted material.
#  76%|███████▌  | 678/896 [2:43:44<47:10, 12.98s/it]
# Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. The candidate's [finish_reason](https://ai.google.dev/api/generate-content#finishreason) is 4. Meaning that the model was reciting from copyrighted material.
# 100%|██████████| 896/896 [3:34:50<00:00, 14.39s/it]

# %%
# Clean up trailing space or newline
for path in tqdm(train_dataset):
  unclean_slide_markdown_path = path / "slide.md"
  with open(unclean_slide_markdown_path, "r") as f:
    slide_md_text = f.read()
  clean_slide_md_text = slide_md_text.strip()
  with open(unclean_slide_markdown_path, "w") as f:
    f.write(clean_slide_md_text)
# Out:
# 100%|██████████| 1001/1001 [00:00<00:00, 5353.43it/s]

# %%
# !zip -r dataset-pdf-clean.zip dataset-pdf
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: dataset-pdf/896/paper.pdf (deflated 32%)
#   adding: dataset-pdf/896/slide.xml (deflated 75%)
#   adding: dataset-pdf/896/slide.md (deflated 66%)
#   adding: dataset-pdf/896/figures_and_tables.txt (deflated 52%)
#   adding: dataset-pdf/896/input_prompt.txt (deflated 67%)
#   adding: dataset-pdf/896/1084.windowed_summarunner_scores.txt (deflated 89%)
#   adding: dataset-pdf/896/extracted_text_with_tag.txt (deflated 67%)
#   adding: dataset-pdf/994/ (stored 0%)
#   adding: dataset-pdf/994/images/ (stored 0%)
#   adding: dataset-pdf/994/images/Figure_1.png (deflated 4%)
#   adding: dataset-pdf/994/slide.pdf (deflated 8%)
#   adding: dataset-pdf/994/paper.tei.xml (deflated 75%)
#   adding: dataset-pdf/994/extracted_text.txt (deflated 63%)
#   adding: dataset-pdf/994/paper.pdf (deflated 4%)
#   adding: dataset-pdf/994/slide.xml (deflated 58%)
#   adding: dataset-pdf/994/slide.md (deflated 55%)
#   adding: dataset-pdf/994/figures_and_tables.txt (deflated 15%)
#   adding: dataset-pdf/994/input_prompt.txt (deflated 63%)
#   adding: dataset-pdf/994/extracted_text_with_tag.txt (deflated 63%)
#   adding: dataset-pdf/994/1205.windowed_summarunner_scores.txt (deflated 86%)
#   adding: dataset-pdf/723/ (stored 0%)
#   adding: dataset-pdf/723/images/ (stored 0%)
#   adding: dataset-pdf/723/images/Table_1.png (deflated 7%)
#   adding: dataset-pdf/723/images/Table_5.png (deflated 5%)
#   adding: dataset-pdf/723/images/Figure_2.png (deflated 11%)
#   adding: dataset-pdf/723/images/Table_2.png (deflated 5%)
#   adding: dataset-pdf/723/images/Figure_3.png (deflated 10%)
#   adding: dataset-pdf/723/images/Table_4.png (deflated 5%)
#   adding: dataset-pdf/723/images/Table_3.png (deflated 5%)
#   adding: dataset-pdf/723/images/Figure_1.png (deflated 7%)
#   adding: dataset-pdf/723/slide.pdf (deflated 28%)
#   adding: dataset-pdf/723/868.windowed_summarunner_scores.txt (deflated 86%)
#   adding: dataset-pdf/723/paper.tei.xml (deflated 68%)
#   adding: dataset-pdf/723/extracted_text.txt (deflated 63%)
#   adding: dataset-pdf/723/paper.pdf (deflated 11%)
#   adding: dataset-pdf/723/slide.xml (deflated 69%)
#   adding: dataset-pdf/723/slide.md (deflated 61%)
#   adding: dataset-pdf/723/figures_and_tables.txt (deflated 56%)
#   adding: dataset-pdf/723/input_prompt.txt (deflated 63%)
#   adding: dataset-pdf/723/extracted_text_with_tag.txt (deflated 63%)
#   adding: dataset-pdf/285/ (stored 0%)
#   adding: dataset-pdf/285/images/ (stored 0%)
#   adding: dataset-pdf/285/images/Table_1.png (deflated 6%)
#   adding: dataset-pdf/285/images/Figure_2.png (deflated 6%)
#   adding: dataset-pdf/285/images/Table_2.png (deflated 6%)
#   adding: dataset-pdf/285/images/Figure_1.png (deflated 4%)
#   adding: dataset-pdf/285/slide.pdf (deflated 13%)
#   adding: dataset-pdf/285/paper.tei.xml (deflated 76%)
#   adding: dataset-pdf/285/335.windowed_summarunner_scores.txt (deflated 87%)
#   adding: dataset-pdf/285/extracted_text.txt (deflated 62%)
#   adding: dataset-pdf/285/paper.pdf (deflated 13%)
#   adding: dataset-pdf/285/slide.xml (deflated 70%)
#   adding: dataset-pdf/285/slide.md (deflated 55%)
#   adding: dataset-pdf/285/figures_and_tables.txt (stored 0%)
#   adding: dataset-pdf/285/input_prompt.txt (deflated 62%)
#   adding: dataset-pdf/285/extracted_text_with_tag.txt (deflated 62%)
#   adding: dataset-pdf/187/ (stored 0%)
#   adding: dataset-pdf/187/images/ (stored 0%)
#   adding: dataset-pdf/187/images/Figure_1.png (deflated 5%)
#   adding: dataset-pdf/187/slide.pdf (deflated 7%)
#   adding: dataset-pdf/187/214.windowed_summarunner_scores.txt (deflated 87%)
#   adding: dataset-pdf/187/paper.tei.xml (deflated 72%)
#   adding: dataset-pdf/187/extracted_text.txt (deflated 63%)
#   adding: dataset-pdf/187/paper.pdf (deflated 6%)
#   adding: dataset-pdf/187/slide.xml (deflated 75%)
#   adding: dataset-pdf/187/slide.md (deflated 63%)
#   adding: dataset-pdf/187/figures_and_tables.txt (deflated 47%)
#   adding: dataset-pdf/187/input_prompt.txt (deflated 63%)
#   adding: dataset-pdf/187/extracted_text_with_tag.txt (deflated 63%)
#   adding: dataset-pdf/412/ (stored 0%)
#   adding: dataset-pdf/412/images/ (stored 0%)
#   adding: dataset-pdf/412/images/Figure_4.png (deflated 4%)
#   adding: dataset-pdf/412/images/Figure_6.png (deflated 3%)
#   adding: dataset-pdf/412/images/Figure_5.png (deflated 3%)
#   adding: dataset-pdf/412/images/Figure_2.png (deflated 3%)
#   adding: dataset-pdf/412/images/Figure_3.png (deflated 3%)
#   adding: dataset-pdf/412/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/412/slide.pdf (deflated 5%)
#   adding: dataset-pdf/412/505.windowed_summarunner_scores.txt (deflated 84%)
#   adding: dataset-pdf/412/paper.tei.xml (deflated 74%)
#   adding: dataset-pdf/412/extracted_text.txt (deflated 65%)
#   adding: dataset-pdf/412/paper.pdf (deflated 16%)
#   adding: dataset-pdf/412/slide.xml (deflated 65%)
#   adding: dataset-pdf/412/slide.md (deflated 55%)
#   adding: dataset-pdf/412/figures_and_tables.txt (deflated 50%)
#   adding: dataset-pdf/412/input_prompt.txt (deflated 65%)
#   adding: dataset-pdf/412/extracted_text_with_tag.txt (deflated 65%)
#   adding: dataset-pdf/819/ (stored 0%)
#   adding: dataset-pdf/819/images/ (stored 0%)
#   adding: dataset-pdf/819/images/Table_1.png (deflated 5%)
#   adding: dataset-pdf/819/images/Figure_2.png (deflated 4%)
#   adding: dataset-pdf/819/images/Table_2.png (deflated 9%)
#   adding: dataset-pdf/819/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/819/slide.pdf (deflated 7%)
#   adding: dataset-pdf/819/paper.tei.xml (deflated 72%)
#   adding: dataset-pdf/819/extracted_text.txt (deflated 64%)
#   adding: dataset-pdf/819/paper.pdf (deflated 12%)
#   adding: dataset-pdf/819/slide.xml (deflated 67%)
#   adding: dataset-pdf/819/slide.md (deflated 61%)
#   adding: dataset-pdf/819/figures_and_tables.txt (deflated 50%)
#   adding: dataset-pdf/819/input_prompt.txt (deflated 64%)
#   adding: dataset-pdf/819/extracted_text_with_tag.txt (deflated 64%)
#   adding: dataset-pdf/819/976.windowed_summarunner_scores.txt (deflated 87%)
#   adding: dataset-pdf/869/ (stored 0%)
#   adding: dataset-pdf/869/images/ (stored 0%)
#   adding: dataset-pdf/869/images/Figure_4.png (deflated 4%)
#   adding: dataset-pdf/869/images/Figure_6.png (deflated 4%)
#   adding: dataset-pdf/869/images/Figure_5.png (deflated 3%)
#   adding: dataset-pdf/869/images/Figure_2.png (deflated 4%)
#   adding: dataset-pdf/869/images/Figure_3.png (deflated 4%)
#   adding: dataset-pdf/869/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/869/slide.pdf (deflated 30%)
#   adding: dataset-pdf/869/1049.windowed_summarunner_scores.txt (deflated 87%)
#   adding: dataset-pdf/869/paper.tei.xml (deflated 72%)
#   adding: dataset-pdf/869/extracted_text.txt (deflated 66%)
#   adding: dataset-pdf/869/paper.pdf (deflated 11%)
#   adding: dataset-pdf/869/slide.xml (deflated 92%)
#   adding: dataset-pdf/869/slide.md (deflated 61%)
#   adding: dataset-pdf/869/figures_and_tables.txt (deflated 55%)
#   adding: dataset-pdf/869/input_prompt.txt (deflated 66%)
#   adding: dataset-pdf/869/extracted_text_with_tag.txt (deflated 66%)
#   adding: dataset-pdf/834/ (stored 0%)
#   adding: dataset-pdf/834/images/ (stored 0%)
#   adding: dataset-pdf/834/images/Figure_2.png (deflated 3%)
#   adding: dataset-pdf/834/images/Figure_3.png (deflated 5%)
#   adding: dataset-pdf/834/images/Figure_1.png (deflated 5%)
#   adding: dataset-pdf/834/slide.pdf (deflated 12%)
#   adding: dataset-pdf/834/paper.tei.xml (deflated 73%)
#   adding: dataset-pdf/834/extracted_text.txt (deflated 66%)
#   adding: dataset-pdf/834/paper.pdf (deflated 10%)
#   adding: dataset-pdf/834/slide.xml (deflated 63%)
#   adding: dataset-pdf/834/slide.md (deflated 56%)
#   adding: dataset-pdf/834/figures_and_tables.txt (deflated 44%)
#   adding: dataset-pdf/834/1000.windowed_summarunner_scores.txt (deflated 87%)
#   adding: dataset-pdf/834/input_prompt.txt (deflated 66%)
#   adding: dataset-pdf/834/extracted_text_with_tag.txt (deflated 66%)
#   adding: dataset-pdf/619/ (stored 0%)
#   adding: dataset-pdf/619/images/ (stored 0%)
#   adding: dataset-pdf/619/images/Figure_4.png (deflated 4%)
#   adding: dataset-pdf/619/images/Figure_2.png (deflated 6%)
#   adding: dataset-pdf/619/images/Figure_3.png (deflated 5%)
#   adding: dataset-pdf/619/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/619/slide.pdf (deflated 9%)
#   adding: dataset-pdf/619/paper.tei.xml (deflated 76%)
#   adding: dataset-pdf/619/extracted_text.txt (deflated 68%)
#   adding: dataset-pdf/619/paper.pdf (deflated 13%)
#   adding: dataset-pdf/619/slide.xml (deflated 68%)
#   adding: dataset-pdf/619/735.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/619/slide.md (deflated 60%)
#   adding: dataset-pdf/619/figures_and_tables.txt (deflated 37%)
#   adding: dataset-pdf/619/input_prompt.txt (deflated 67%)
#   adding: dataset-pdf/619/extracted_text_with_tag.txt (deflated 68%)
#   adding: dataset-pdf/830/ (stored 0%)
#   adding: dataset-pdf/830/images/ (stored 0%)
#   adding: dataset-pdf/830/images/Table_1.png (deflated 1%)
#   adding: dataset-pdf/830/images/Figure_4.png (deflated 2%)
#   adding: dataset-pdf/830/images/Figure_5.png (deflated 3%)
#   adding: dataset-pdf/830/images/Figure_2.png (deflated 3%)
#   adding: dataset-pdf/830/images/Figure_3.png (deflated 4%)
#   adding: dataset-pdf/830/images/Figure_1.png (deflated 1%)
#   adding: dataset-pdf/830/slide.pdf (deflated 42%)
#   adding: dataset-pdf/830/995.windowed_summarunner_scores.txt (deflated 87%)
#   adding: dataset-pdf/830/paper.tei.xml (deflated 74%)
#   adding: dataset-pdf/830/extracted_text.txt (deflated 63%)
#   adding: dataset-pdf/830/paper.pdf (deflated 15%)
#   adding: dataset-pdf/830/slide.xml (deflated 91%)
#   adding: dataset-pdf/830/slide.md (deflated 59%)
#   adding: dataset-pdf/830/figures_and_tables.txt (deflated 46%)
#   adding: dataset-pdf/830/input_prompt.txt (deflated 64%)
#   adding: dataset-pdf/830/extracted_text_with_tag.txt (deflated 63%)
#   adding: dataset-pdf/169/ (stored 0%)
#   adding: dataset-pdf/169/194.windowed_summarunner_scores.txt (deflated 84%)
#   adding: dataset-pdf/169/images/ (stored 0%)
#   adding: dataset-pdf/169/images/Figure_4.png (deflated 4%)
#   adding: dataset-pdf/169/images/Figure_6.png (deflated 5%)
#   adding: dataset-pdf/169/images/Figure_5.png (deflated 3%)
#   adding: dataset-pdf/169/images/Figure_2.png (deflated 1%)
#   adding: dataset-pdf/169/images/Figure_3.png (deflated 2%)
#   adding: dataset-pdf/169/images/Figure_1.png (deflated 2%)
#   adding: dataset-pdf/169/slide.pdf (deflated 20%)
#   adding: dataset-pdf/169/paper.tei.xml (deflated 73%)
#   adding: dataset-pdf/169/extracted_text.txt (deflated 63%)
#   adding: dataset-pdf/169/paper.pdf (deflated 20%)
#   adding: dataset-pdf/169/slide.xml (deflated 62%)
#   adding: dataset-pdf/169/slide.md (deflated 64%)
#   adding: dataset-pdf/169/figures_and_tables.txt (deflated 56%)
#   adding: dataset-pdf/169/input_prompt.txt (deflated 64%)
#   adding: dataset-pdf/169/extracted_text_with_tag.txt (deflated 63%)
#   adding: dataset-pdf/178/ (stored 0%)
#   adding: dataset-pdf/178/204.windowed_summarunner_scores.txt (deflated 90%)
#   adding: dataset-pdf/178/images/ (stored 0%)
#   adding: dataset-pdf/178/images/Table_7.png (deflated 2%)
#   adding: dataset-pdf/178/images/Table_1.png (deflated 3%)
#   adding: dataset-pdf/178/images/Figure_4.png (deflated 2%)
#   adding: dataset-pdf/178/images/Table_5.png (deflated 3%)
#   adding: dataset-pdf/178/images/Figure_6.png (deflated 7%)
#   adding: dataset-pdf/178/images/Table_6.png (deflated 6%)
#   adding: dataset-pdf/178/images/Figure_5.png (deflated 6%)
#   adding: dataset-pdf/178/images/Figure_2.png (deflated 5%)
#   adding: dataset-pdf/178/images/Table_2.png (deflated 4%)
#   adding: dataset-pdf/178/images/Figure_3.png (deflated 4%)
#   adding: dataset-pdf/178/images/Table_3.png (deflated 4%)
#   adding: dataset-pdf/178/images/Figure_1.png (deflated 5%)
#   adding: dataset-pdf/178/images/Figure_8.png (deflated 7%)
#   adding: dataset-pdf/178/images/Figure_7.png (deflated 7%)
#   adding: dataset-pdf/178/slide.pdf (deflated 4%)
#   adding: dataset-pdf/178/paper.tei.xml (deflated 78%)
#   adding: dataset-pdf/178/extracted_text.txt (deflated 67%)
#   adding: dataset-pdf/178/paper.pdf (deflated 8%)
#   adding: dataset-pdf/178/slide.xml (deflated 89%)
#   adding: dataset-pdf/178/slide.md (deflated 63%)
#   adding: dataset-pdf/178/figures_and_tables.txt (deflated 59%)
#   adding: dataset-pdf/178/input_prompt.txt (deflated 67%)
#   adding: dataset-pdf/178/extracted_text_with_tag.txt (deflated 67%)
#   adding: dataset-pdf/543/ (stored 0%)
#   adding: dataset-pdf/543/images/ (stored 0%)
#   adding: dataset-pdf/543/images/Table_1.png (deflated 5%)
#   adding: dataset-pdf/543/images/Figure_4.png (deflated 4%)
#   adding: dataset-pdf/543/images/Table_5.png (deflated 3%)
#   adding: dataset-pdf/543/images/Figure_6.png (deflated 4%)
#   adding: dataset-pdf/543/images/Table_6.png (deflated 5%)
#   adding: dataset-pdf/543/images/Figure_5.png (deflated 4%)
#   adding: dataset-pdf/543/images/Figure_2.png (deflated 7%)
#   adding: dataset-pdf/543/images/Table_2.png (deflated 3%)
#   adding: dataset-pdf/543/images/Figure_3.png (deflated 7%)
#   adding: dataset-pdf/543/images/Table_4.png (deflated 7%)
#   adding: dataset-pdf/543/images/Table_3.png (deflated 4%)
#   adding: dataset-pdf/543/images/Figure_1.png (deflated 8%)
#   adding: dataset-pdf/543/slide.pdf (deflated 11%)
#   adding: dataset-pdf/543/650.windowed_summarunner_scores.txt (deflated 87%)
#   adding: dataset-pdf/543/paper.tei.xml (deflated 72%)
#   adding: dataset-pdf/543/extracted_text.txt (deflated 66%)
#   adding: dataset-pdf/543/paper.pdf (deflated 10%)
#   adding: dataset-pdf/543/slide.xml (deflated 78%)
#   adding: dataset-pdf/543/slide.md (deflated 62%)
#   adding: dataset-pdf/543/figures_and_tables.txt (deflated 56%)
#   adding: dataset-pdf/543/input_prompt.txt (deflated 66%)
#   adding: dataset-pdf/543/extracted_text_with_tag.txt (deflated 66%)
#   adding: dataset-pdf/26/ (stored 0%)
#   adding: dataset-pdf/26/images/ (stored 0%)
#   adding: dataset-pdf/26/images/Table_1.png (deflated 6%)
#   adding: dataset-pdf/26/images/Figure_4.png (deflated 5%)
#   adding: dataset-pdf/26/images/Table_5.png (deflated 6%)
#   adding: dataset-pdf/26/images/Figure_6.png (deflated 7%)
#   adding: dataset-pdf/26/images/Table_6.png (deflated 4%)
#   adding: dataset-pdf/26/images/Figure_5.png (deflated 4%)
#   adding: dataset-pdf/26/images/Figure_2.png (deflated 5%)
#   adding: dataset-pdf/26/images/Table_2.png (deflated 3%)
#   adding: dataset-pdf/26/images/Figure_3.png (deflated 2%)
#   adding: dataset-pdf/26/images/Table_4.png (deflated 5%)
#   adding: dataset-pdf/26/images/Table_3.png (deflated 5%)
#   adding: dataset-pdf/26/images/Figure_1.png (deflated 5%)
#   adding: dataset-pdf/26/images/Figure_7.png (deflated 8%)
#   adding: dataset-pdf/26/slide.pdf (deflated 29%)
#   adding: dataset-pdf/26/paper.tei.xml (deflated 75%)
#   adding: dataset-pdf/26/32.windowed_summarunner_scores.txt (deflated 89%)
#   adding: dataset-pdf/26/extracted_text.txt (deflated 68%)
#   adding: dataset-pdf/26/paper.pdf (deflated 9%)
#   adding: dataset-pdf/26/slide.xml (deflated 75%)
#   adding: dataset-pdf/26/slide.md (deflated 60%)
#   adding: dataset-pdf/26/figures_and_tables.txt (deflated 55%)
#   adding: dataset-pdf/26/input_prompt.txt (deflated 68%)
#   adding: dataset-pdf/26/extracted_text_with_tag.txt (deflated 68%)
#   adding: dataset-pdf/111/ (stored 0%)
#   adding: dataset-pdf/111/127.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/111/images/ (stored 0%)
#   adding: dataset-pdf/111/images/Figure_2.png (deflated 6%)
#   adding: dataset-pdf/111/images/Figure_3.png (deflated 6%)
#   adding: dataset-pdf/111/images/Figure_1.png (deflated 4%)
#   adding: dataset-pdf/111/slide.pdf (deflated 10%)
#   adding: dataset-pdf/111/paper.tei.xml (deflated 72%)
#   adding: dataset-pdf/111/extracted_text.txt (deflated 65%)
#   adding: dataset-pdf/111/paper.pdf (deflated 1%)
#   adding: dataset-pdf/111/slide.xml (deflated 76%)
#   adding: dataset-pdf/111/slide.md (deflated 63%)
#   adding: dataset-pdf/111/figures_and_tables.txt (deflated 32%)
#   adding: dataset-pdf/111/input_prompt.txt (deflated 65%)
#   adding: dataset-pdf/111/extracted_text_with_tag.txt (deflated 65%)
#   adding: dataset-pdf/816/ (stored 0%)
#   adding: dataset-pdf/816/972.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/816/images/ (stored 0%)
#   adding: dataset-pdf/816/images/Figure_1.png (deflated 8%)
#   adding: dataset-pdf/816/slide.pdf (deflated 17%)
#   adding: dataset-pdf/816/paper.tei.xml (deflated 74%)
#   adding: dataset-pdf/816/extracted_text.txt (deflated 67%)
#   adding: dataset-pdf/816/paper.pdf (deflated 22%)
#   adding: dataset-pdf/816/slide.xml (deflated 72%)
#   adding: dataset-pdf/816/slide.md (deflated 65%)
#   adding: dataset-pdf/816/figures_and_tables.txt (deflated 12%)
#   adding: dataset-pdf/816/input_prompt.txt (deflated 67%)
#   adding: dataset-pdf/816/extracted_text_with_tag.txt (deflated 67%)
#   adding: dataset-pdf/531/ (stored 0%)
#   adding: dataset-pdf/531/images/ (stored 0%)
#   adding: dataset-pdf/531/images/Table_1.png (deflated 3%)
#   adding: dataset-pdf/531/images/Figure_4.png (deflated 5%)
#   adding: dataset-pdf/531/images/Figure_6.png (deflated 5%)
#   adding: dataset-pdf/531/images/Figure_5.png (deflated 5%)
#   adding: dataset-pdf/531/images/Figure_2.png (deflated 6%)
#   adding: dataset-pdf/531/images/Figure_3.png (deflated 7%)
#   adding: dataset-pdf/531/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/531/images/Figure_8.png (deflated 4%)
#   adding: dataset-pdf/531/images/Figure_7.png (deflated 4%)
#   adding: dataset-pdf/531/slide.pdf (deflated 19%)
#   adding: dataset-pdf/531/paper.tei.xml (deflated 76%)
#   adding: dataset-pdf/531/638.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/531/extracted_text.txt (deflated 66%)
#   adding: dataset-pdf/531/paper.pdf (deflated 13%)
#   adding: dataset-pdf/531/slide.xml (deflated 60%)
#   adding: dataset-pdf/531/slide.md (deflated 56%)
#   adding: dataset-pdf/531/figures_and_tables.txt (deflated 56%)
#   adding: dataset-pdf/531/input_prompt.txt (deflated 66%)
#   adding: dataset-pdf/531/extracted_text_with_tag.txt (deflated 66%)
#   adding: dataset-pdf/342/ (stored 0%)
#   adding: dataset-pdf/342/images/ (stored 0%)
#   adding: dataset-pdf/342/images/Figure_14.png (deflated 3%)
#   adding: dataset-pdf/342/images/Table_1.png (deflated 5%)
#   adding: dataset-pdf/342/images/Figure_4.png (deflated 4%)
#   adding: dataset-pdf/342/images/Table_5.png (deflated 3%)
#   adding: dataset-pdf/342/images/Figure_9.png (deflated 4%)
#   adding: dataset-pdf/342/images/Figure_5.png (deflated 6%)
#   adding: dataset-pdf/342/images/Figure_2.png (deflated 5%)
#   adding: dataset-pdf/342/images/Table_2.png (deflated 3%)
#   adding: dataset-pdf/342/images/Figure_11.png (deflated 5%)
#   adding: dataset-pdf/342/images/Table_4.png (deflated 2%)
#   adding: dataset-pdf/342/images/Table_3.png (deflated 4%)
#   adding: dataset-pdf/342/images/Figure_10.png (deflated 5%)
#   adding: dataset-pdf/342/images/Figure_7.png (deflated 5%)
#   adding: dataset-pdf/342/slide.pdf (deflated 25%)
#   adding: dataset-pdf/342/paper.tei.xml (deflated 77%)
#   adding: dataset-pdf/342/extracted_text.txt (deflated 69%)
#   adding: dataset-pdf/342/paper.pdf (deflated 9%)
#   adding: dataset-pdf/342/slide.xml (deflated 76%)
#   adding: dataset-pdf/342/slide.md (deflated 66%)
#   adding: dataset-pdf/342/figures_and_tables.txt (deflated 55%)
#   adding: dataset-pdf/342/input_prompt.txt (deflated 69%)
#   adding: dataset-pdf/342/extracted_text_with_tag.txt (deflated 69%)
#   adding: dataset-pdf/342/408.windowed_summarunner_scores.txt (deflated 91%)
#   adding: dataset-pdf/1009/ (stored 0%)
#   adding: dataset-pdf/1009/images/ (stored 0%)
#   adding: dataset-pdf/1009/images/Table_1.png (deflated 6%)
#   adding: dataset-pdf/1009/images/Figure_4.png (deflated 8%)
#   adding: dataset-pdf/1009/images/Figure_6.png (deflated 3%)
#   adding: dataset-pdf/1009/images/Figure_9.png (deflated 3%)
#   adding: dataset-pdf/1009/images/Figure_5.png (deflated 3%)
#   adding: dataset-pdf/1009/images/Figure_2.png (deflated 3%)
#   adding: dataset-pdf/1009/images/Figure_3.png (deflated 1%)
#   adding: dataset-pdf/1009/images/Figure_1.png (deflated 4%)
#   adding: dataset-pdf/1009/images/Figure_8.png (deflated 3%)
#   adding: dataset-pdf/1009/images/Figure_7.png (deflated 16%)
#   adding: dataset-pdf/1009/1220.windowed_summarunner_scores.txt (deflated 86%)
#   adding: dataset-pdf/1009/slide.pdf (deflated 14%)
#   adding: dataset-pdf/1009/paper.tei.xml (deflated 74%)
#   adding: dataset-pdf/1009/extracted_text.txt (deflated 63%)
#   adding: dataset-pdf/1009/paper.pdf (deflated 4%)
#   adding: dataset-pdf/1009/slide.xml (deflated 64%)
#   adding: dataset-pdf/1009/slide.md (deflated 57%)
#   adding: dataset-pdf/1009/figures_and_tables.txt (deflated 50%)
#   adding: dataset-pdf/1009/input_prompt.txt (deflated 63%)
#   adding: dataset-pdf/1009/extracted_text_with_tag.txt (deflated 63%)
#   adding: dataset-pdf/321/ (stored 0%)
#   adding: dataset-pdf/321/images/ (stored 0%)
#   adding: dataset-pdf/321/images/Figure_2.png (deflated 3%)
#   adding: dataset-pdf/321/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/321/slide.pdf (deflated 5%)
#   adding: dataset-pdf/321/paper.tei.xml (deflated 71%)
#   adding: dataset-pdf/321/extracted_text.txt (deflated 64%)
#   adding: dataset-pdf/321/paper.pdf (deflated 19%)
#   adding: dataset-pdf/321/386.windowed_summarunner_scores.txt (deflated 83%)
#   adding: dataset-pdf/321/slide.xml (deflated 68%)
#   adding: dataset-pdf/321/slide.md (deflated 53%)
#   adding: dataset-pdf/321/figures_and_tables.txt (deflated 47%)
#   adding: dataset-pdf/321/input_prompt.txt (deflated 64%)
#   adding: dataset-pdf/321/extracted_text_with_tag.txt (deflated 64%)
#   adding: dataset-pdf/873/ (stored 0%)
#   adding: dataset-pdf/873/images/ (stored 0%)
#   adding: dataset-pdf/873/images/Table_1.png (deflated 3%)
#   adding: dataset-pdf/873/images/Figure_4.png (deflated 3%)
#   adding: dataset-pdf/873/images/Table_5.png (deflated 4%)
#   adding: dataset-pdf/873/images/Figure_6.png (deflated 4%)
#   adding: dataset-pdf/873/images/Figure_9.png (deflated 4%)
#   adding: dataset-pdf/873/images/Figure_5.png (deflated 4%)
#   adding: dataset-pdf/873/images/Figure_2.png (deflated 4%)
#   adding: dataset-pdf/873/images/Table_2.png (deflated 3%)
#   adding: dataset-pdf/873/images/Figure_3.png (deflated 4%)
#   adding: dataset-pdf/873/images/Table_4.png (deflated 10%)
#   adding: dataset-pdf/873/images/Table_3.png (deflated 4%)
#   adding: dataset-pdf/873/images/Figure_1.png (deflated 5%)
#   adding: dataset-pdf/873/images/Figure_8.png (deflated 3%)
#   adding: dataset-pdf/873/images/Figure_10.png (deflated 2%)
#   adding: dataset-pdf/873/images/Figure_7.png (deflated 5%)
#   adding: dataset-pdf/873/slide.pdf (deflated 57%)
#   adding: dataset-pdf/873/paper.tei.xml (deflated 75%)
#   adding: dataset-pdf/873/extracted_text.txt (deflated 66%)
#   adding: dataset-pdf/873/paper.pdf (deflated 17%)
#   adding: dataset-pdf/873/1055.windowed_summarunner_scores.txt (deflated 89%)
#   adding: dataset-pdf/873/slide.xml (deflated 92%)
#   adding: dataset-pdf/873/slide.md (deflated 63%)
#   adding: dataset-pdf/873/figures_and_tables.txt (deflated 58%)
#   adding: dataset-pdf/873/input_prompt.txt (deflated 66%)
#   adding: dataset-pdf/873/extracted_text_with_tag.txt (deflated 66%)
#   adding: dataset-pdf/63/ (stored 0%)
#   adding: dataset-pdf/63/images/ (stored 0%)
#   adding: dataset-pdf/63/slide.pdf (deflated 17%)
#   adding: dataset-pdf/63/paper.tei.xml (deflated 70%)
#   adding: dataset-pdf/63/extracted_text.txt (deflated 56%)
#   adding: dataset-pdf/63/paper.pdf (deflated 19%)
#   adding: dataset-pdf/63/slide.xml (deflated 72%)
#   adding: dataset-pdf/63/slide.md (deflated 62%)
#   adding: dataset-pdf/63/figures_and_tables.txt (stored 0%)
#   adding: dataset-pdf/63/72.windowed_summarunner_scores.txt (deflated 80%)
#   adding: dataset-pdf/63/input_prompt.txt (deflated 55%)
#   adding: dataset-pdf/63/extracted_text_with_tag.txt (deflated 56%)
#   adding: dataset-pdf/39/ (stored 0%)
#   adding: dataset-pdf/39/45.windowed_summarunner_scores.txt (deflated 86%)
#   adding: dataset-pdf/39/images/ (stored 0%)
#   adding: dataset-pdf/39/images/Figure_4.png (deflated 2%)
#   adding: dataset-pdf/39/images/Figure_6.png (deflated 8%)
#   adding: dataset-pdf/39/images/Figure_9.png (deflated 3%)
#   adding: dataset-pdf/39/images/Figure_5.png (deflated 4%)
#   adding: dataset-pdf/39/images/Figure_2.png (deflated 3%)
#   adding: dataset-pdf/39/images/Figure_3.png (deflated 4%)
#   adding: dataset-pdf/39/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/39/images/Figure_8.png (deflated 3%)
#   adding: dataset-pdf/39/images/Figure_10.png (deflated 4%)
#   adding: dataset-pdf/39/images/Figure_7.png (deflated 9%)
#   adding: dataset-pdf/39/slide.pdf (deflated 9%)
#   adding: dataset-pdf/39/paper.tei.xml (deflated 76%)
#   adding: dataset-pdf/39/extracted_text.txt (deflated 70%)
#   adding: dataset-pdf/39/paper.pdf (deflated 21%)
#   adding: dataset-pdf/39/slide.xml (deflated 73%)
#   adding: dataset-pdf/39/slide.md (deflated 64%)
#   adding: dataset-pdf/39/figures_and_tables.txt (deflated 64%)
#   adding: dataset-pdf/39/input_prompt.txt (deflated 70%)
#   adding: dataset-pdf/39/extracted_text_with_tag.txt (deflated 70%)
#   adding: dataset-pdf/505/ (stored 0%)
#   adding: dataset-pdf/505/images/ (stored 0%)
#   adding: dataset-pdf/505/images/Table_1.png (deflated 5%)
#   adding: dataset-pdf/505/images/Figure_5.png (deflated 4%)
#   adding: dataset-pdf/505/images/Figure_3.png (deflated 2%)
#   adding: dataset-pdf/505/images/Figure_1.png (deflated 4%)
#   adding: dataset-pdf/505/images/Figure_8.png (deflated 4%)
#   adding: dataset-pdf/505/images/Figure_7.png (deflated 3%)
#   adding: dataset-pdf/505/slide.pdf (deflated 12%)
#   adding: dataset-pdf/505/paper.tei.xml (deflated 70%)
#   adding: dataset-pdf/505/extracted_text.txt (deflated 64%)
#   adding: dataset-pdf/505/paper.pdf (deflated 7%)
#   adding: dataset-pdf/505/slide.xml (deflated 74%)
#   adding: dataset-pdf/505/slide.md (deflated 66%)
#   adding: dataset-pdf/505/figures_and_tables.txt (deflated 51%)
#   adding: dataset-pdf/505/input_prompt.txt (deflated 64%)
#   adding: dataset-pdf/505/extracted_text_with_tag.txt (deflated 64%)
#   adding: dataset-pdf/505/611.windowed_summarunner_scores.txt (deflated 86%)
#   adding: dataset-pdf/828/ (stored 0%)
#   adding: dataset-pdf/828/images/ (stored 0%)
#   adding: dataset-pdf/828/images/Table_1.png (deflated 5%)
#   adding: dataset-pdf/828/images/Figure_6.png (deflated 4%)
#   adding: dataset-pdf/828/images/Figure_5.png (deflated 5%)
#   adding: dataset-pdf/828/images/Figure_2.png (deflated 5%)
#   adding: dataset-pdf/828/images/Table_2.png (deflated 4%)
#   adding: dataset-pdf/828/images/Figure_3.png (deflated 4%)
#   adding: dataset-pdf/828/images/Table_3.png (deflated 4%)
#   adding: dataset-pdf/828/images/Figure_1.png (deflated 5%)
#   adding: dataset-pdf/828/images/Figure_7.png (deflated 3%)
#   adding: dataset-pdf/828/992.windowed_summarunner_scores.txt (deflated 89%)
#   adding: dataset-pdf/828/slide.pdf (deflated 7%)
#   adding: dataset-pdf/828/paper.tei.xml (deflated 74%)
#   adding: dataset-pdf/828/extracted_text.txt (deflated 69%)
#   adding: dataset-pdf/828/paper.pdf (deflated 20%)
#   adding: dataset-pdf/828/slide.xml (deflated 69%)
#   adding: dataset-pdf/828/slide.md (deflated 58%)
#   adding: dataset-pdf/828/figures_and_tables.txt (deflated 52%)
#   adding: dataset-pdf/828/input_prompt.txt (deflated 69%)
#   adding: dataset-pdf/828/extracted_text_with_tag.txt (deflated 69%)
#   adding: dataset-pdf/104/ (stored 0%)
#   adding: dataset-pdf/104/images/ (stored 0%)
#   adding: dataset-pdf/104/images/Table_IV.png (deflated 10%)
#   adding: dataset-pdf/104/images/Table_III.png (deflated 7%)
#   adding: dataset-pdf/104/images/Figure_2.png (deflated 12%)
#   adding: dataset-pdf/104/images/Figure_3.png (deflated 10%)
#   adding: dataset-pdf/104/images/Figure_1.png (deflated 12%)
#   adding: dataset-pdf/104/slide.pdf (deflated 21%)
#   adding: dataset-pdf/104/119.windowed_summarunner_scores.txt (deflated 87%)
#   adding: dataset-pdf/104/paper.tei.xml (deflated 72%)
#   adding: dataset-pdf/104/extracted_text.txt (deflated 64%)
#   adding: dataset-pdf/104/paper.pdf (deflated 4%)
#   adding: dataset-pdf/104/slide.xml (deflated 69%)
#   adding: dataset-pdf/104/slide.md (deflated 65%)
#   adding: dataset-pdf/104/figures_and_tables.txt (deflated 55%)
#   adding: dataset-pdf/104/input_prompt.txt (deflated 64%)
#   adding: dataset-pdf/104/extracted_text_with_tag.txt (deflated 64%)
#   adding: dataset-pdf/208/ (stored 0%)
#   adding: dataset-pdf/208/images/ (stored 0%)
#   adding: dataset-pdf/208/images/Figure_4.png (deflated 9%)
#   adding: dataset-pdf/208/images/Figure_6.png (deflated 1%)
#   adding: dataset-pdf/208/images/Figure_9.png (deflated 1%)
#   adding: dataset-pdf/208/images/Figure_5.png (deflated 13%)
#   adding: dataset-pdf/208/images/Figure_2.png (deflated 3%)
#   adding: dataset-pdf/208/images/Figure_3.png (deflated 7%)
#   adding: dataset-pdf/208/images/Figure_1.png (deflated 0%)
#   adding: dataset-pdf/208/images/Figure_8.png (deflated 2%)
#   adding: dataset-pdf/208/images/Figure_7.png (deflated 1%)
#   adding: dataset-pdf/208/slide.pdf (deflated 5%)
#   adding: dataset-pdf/208/paper.tei.xml (deflated 74%)
#   adding: dataset-pdf/208/extracted_text.txt (deflated 65%)
#   adding: dataset-pdf/208/paper.pdf (deflated 5%)
#   adding: dataset-pdf/208/slide.xml (deflated 73%)
#   adding: dataset-pdf/208/slide.md (deflated 60%)
#   adding: dataset-pdf/208/figures_and_tables.txt (deflated 51%)
#   adding: dataset-pdf/208/input_prompt.txt (deflated 65%)
#   adding: dataset-pdf/208/extracted_text_with_tag.txt (deflated 65%)
#   adding: dataset-pdf/208/239.windowed_summarunner_scores.txt (deflated 86%)
#   adding: dataset-pdf/454/ (stored 0%)
#   adding: dataset-pdf/454/images/ (stored 0%)
#   adding: dataset-pdf/454/images/Figure_4.png (deflated 3%)
#   adding: dataset-pdf/454/images/Figure_6.png (deflated 2%)
#   adding: dataset-pdf/454/images/Figure_2.png (deflated 4%)
#   adding: dataset-pdf/454/images/Figure_1.png (deflated 4%)
#   adding: dataset-pdf/454/images/Figure_8.png (deflated 3%)
#   adding: dataset-pdf/454/slide.pdf (deflated 13%)
#   adding: dataset-pdf/454/paper.tei.xml (deflated 76%)
#   adding: dataset-pdf/454/extracted_text.txt (deflated 70%)
#   adding: dataset-pdf/454/paper.pdf (deflated 8%)
#   adding: dataset-pdf/454/slide.xml (deflated 68%)
#   adding: dataset-pdf/454/554.windowed_summarunner_scores.txt (deflated 89%)
#   adding: dataset-pdf/454/slide.md (deflated 59%)
#   adding: dataset-pdf/454/figures_and_tables.txt (deflated 53%)
#   adding: dataset-pdf/454/input_prompt.txt (deflated 70%)
#   adding: dataset-pdf/454/extracted_text_with_tag.txt (deflated 70%)
#   adding: dataset-pdf/374/ (stored 0%)
#   adding: dataset-pdf/374/images/ (stored 0%)
#   adding: dataset-pdf/374/images/Table_1.png (deflated 6%)
#   adding: dataset-pdf/374/images/Figure_9.png (deflated 4%)
#   adding: dataset-pdf/374/images/Figure_2.png (deflated 2%)
#   adding: dataset-pdf/374/images/Table_2.png (deflated 4%)
#   adding: dataset-pdf/374/images/Figure_3.png (deflated 3%)
#   adding: dataset-pdf/374/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/374/images/Figure_8.png (deflated 3%)
#   adding: dataset-pdf/374/images/Figure_7.png (deflated 4%)
#   adding: dataset-pdf/374/slide.pdf (deflated 19%)
#   adding: dataset-pdf/374/paper.tei.xml (deflated 76%)
#   adding: dataset-pdf/374/extracted_text.txt (deflated 67%)
#   adding: dataset-pdf/374/paper.pdf (deflated 2%)
#   adding: dataset-pdf/374/slide.xml (deflated 73%)
#   adding: dataset-pdf/374/slide.md (deflated 62%)
#   adding: dataset-pdf/374/figures_and_tables.txt (deflated 51%)
#   adding: dataset-pdf/374/input_prompt.txt (deflated 67%)
#   adding: dataset-pdf/374/extracted_text_with_tag.txt (deflated 67%)
#   adding: dataset-pdf/374/450.windowed_summarunner_scores.txt (deflated 89%)
#   adding: dataset-pdf/497/ (stored 0%)
#   adding: dataset-pdf/497/images/ (stored 0%)
#   adding: dataset-pdf/497/images/Table_1.png (deflated 3%)
#   adding: dataset-pdf/497/images/Figure_1.png (deflated 8%)
#   adding: dataset-pdf/497/slide.pdf (deflated 36%)
#   adding: dataset-pdf/497/paper.tei.xml (deflated 73%)
#   adding: dataset-pdf/497/extracted_text.txt (deflated 62%)
#   adding: dataset-pdf/497/paper.pdf (deflated 22%)
#   adding: dataset-pdf/497/slide.xml (deflated 71%)
#   adding: dataset-pdf/497/slide.md (deflated 59%)
#   adding: dataset-pdf/497/figures_and_tables.txt (stored 0%)
#   adding: dataset-pdf/497/input_prompt.txt (deflated 62%)
#   adding: dataset-pdf/497/extracted_text_with_tag.txt (deflated 62%)
#   adding: dataset-pdf/497/602.windowed_summarunner_scores.txt (deflated 86%)
#   adding: dataset-pdf/112/ (stored 0%)
#   adding: dataset-pdf/112/images/ (stored 0%)
#   adding: dataset-pdf/112/images/Table_1.png (deflated 6%)
#   adding: dataset-pdf/112/images/Figure_4.png (deflated 4%)
#   adding: dataset-pdf/112/images/Figure_6.png (deflated 4%)
#   adding: dataset-pdf/112/images/Figure_5.png (deflated 5%)
#   adding: dataset-pdf/112/images/Figure_2.png (deflated 5%)
#   adding: dataset-pdf/112/images/Figure_3.png (deflated 5%)
#   adding: dataset-pdf/112/images/Figure_1.png (deflated 5%)
#   adding: dataset-pdf/112/images/Figure_7.png (deflated 5%)
#   adding: dataset-pdf/112/slide.pdf (deflated 13%)
#   adding: dataset-pdf/112/paper.tei.xml (deflated 73%)
#   adding: dataset-pdf/112/extracted_text.txt (deflated 67%)
#   adding: dataset-pdf/112/paper.pdf (deflated 13%)
#   adding: dataset-pdf/112/128.windowed_summarunner_scores.txt (deflated 85%)
#   adding: dataset-pdf/112/slide.xml (deflated 66%)
#   adding: dataset-pdf/112/slide.md (deflated 62%)
#   adding: dataset-pdf/112/figures_and_tables.txt (deflated 58%)
#   adding: dataset-pdf/112/input_prompt.txt (deflated 67%)
#   adding: dataset-pdf/112/extracted_text_with_tag.txt (deflated 67%)
#   adding: dataset-pdf/925/ (stored 0%)
#   adding: dataset-pdf/925/images/ (stored 0%)
#   adding: dataset-pdf/925/images/Table_1.png (deflated 7%)
#   adding: dataset-pdf/925/images/Figure_4.png (deflated 6%)
#   adding: dataset-pdf/925/images/Figure_6.png (deflated 13%)
#   adding: dataset-pdf/925/images/Figure_5.png (deflated 7%)
#   adding: dataset-pdf/925/images/Figure_2.png (deflated 7%)
#   adding: dataset-pdf/925/images/Table_2.png (deflated 11%)
#   adding: dataset-pdf/925/images/Figure_3.png (deflated 6%)
#   adding: dataset-pdf/925/images/Table_3.png (deflated 6%)
#   adding: dataset-pdf/925/images/Figure_1.png (deflated 10%)
#   adding: dataset-pdf/925/slide.pdf (deflated 43%)
#   adding: dataset-pdf/925/1119.windowed_summarunner_scores.txt (deflated 87%)
#   adding: dataset-pdf/925/paper.tei.xml (deflated 78%)
#   adding: dataset-pdf/925/extracted_text.txt (deflated 66%)
#   adding: dataset-pdf/925/paper.pdf (deflated 4%)
#   adding: dataset-pdf/925/slide.xml (deflated 71%)
#   adding: dataset-pdf/925/slide.md (deflated 65%)
#   adding: dataset-pdf/925/figures_and_tables.txt (deflated 57%)
#   adding: dataset-pdf/925/input_prompt.txt (deflated 69%)
#   adding: dataset-pdf/925/extracted_text_with_tag.txt (deflated 66%)
#   adding: dataset-pdf/1067/ (stored 0%)
#   adding: dataset-pdf/1067/images/ (stored 0%)
#   adding: dataset-pdf/1067/images/Table_1.png (deflated 4%)
#   adding: dataset-pdf/1067/images/Figure_4.png (deflated 1%)
#   adding: dataset-pdf/1067/images/Figure_6.png (deflated 0%)
#   adding: dataset-pdf/1067/images/Figure_9.png (deflated 1%)
#   adding: dataset-pdf/1067/images/Figure_5.png (deflated 1%)
#   adding: dataset-pdf/1067/images/Figure_2.png (deflated 4%)
#   adding: dataset-pdf/1067/images/Table_2.png (deflated 5%)
#   adding: dataset-pdf/1067/images/Figure_3.png (deflated 2%)
#   adding: dataset-pdf/1067/images/Table_4.png (deflated 3%)
#   adding: dataset-pdf/1067/images/Figure_1.png (deflated 2%)
#   adding: dataset-pdf/1067/images/Figure_8.png (deflated 1%)
#   adding: dataset-pdf/1067/images/Figure_7.png (deflated 0%)
#   adding: dataset-pdf/1067/slide.pdf (deflated 5%)
#   adding: dataset-pdf/1067/paper.tei.xml (deflated 72%)
#   adding: dataset-pdf/1067/extracted_text.txt (deflated 67%)
#   adding: dataset-pdf/1067/paper.pdf (deflated 4%)
#   adding: dataset-pdf/1067/1283.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/1067/slide.xml (deflated 73%)
#   adding: dataset-pdf/1067/slide.md (deflated 65%)
#   adding: dataset-pdf/1067/figures_and_tables.txt (deflated 60%)
#   adding: dataset-pdf/1067/input_prompt.txt (deflated 67%)
#   adding: dataset-pdf/1067/extracted_text_with_tag.txt (deflated 67%)
#   adding: dataset-pdf/914/ (stored 0%)
#   adding: dataset-pdf/914/images/ (stored 0%)
#   adding: dataset-pdf/914/images/Figure_1.png (deflated 4%)
#   adding: dataset-pdf/914/slide.pdf (deflated 4%)
#   adding: dataset-pdf/914/paper.tei.xml (deflated 75%)
#   adding: dataset-pdf/914/1107.windowed_summarunner_scores.txt (deflated 87%)
#   adding: dataset-pdf/914/extracted_text.txt (deflated 64%)
#   adding: dataset-pdf/914/paper.pdf (deflated 12%)
#   adding: dataset-pdf/914/slide.xml (deflated 65%)
#   adding: dataset-pdf/914/slide.md (deflated 58%)
#   adding: dataset-pdf/914/figures_and_tables.txt (deflated 34%)
#   adding: dataset-pdf/914/input_prompt.txt (deflated 64%)
#   adding: dataset-pdf/914/extracted_text_with_tag.txt (deflated 64%)
#   adding: dataset-pdf/377/ (stored 0%)
#   adding: dataset-pdf/377/images/ (stored 0%)
#   adding: dataset-pdf/377/images/Table_1.png (deflated 6%)
#   adding: dataset-pdf/377/images/Figure_4.png (deflated 5%)
#   adding: dataset-pdf/377/images/Table_5.png (deflated 4%)
#   adding: dataset-pdf/377/images/Figure_6.png (deflated 3%)
#   adding: dataset-pdf/377/images/Figure_5.png (deflated 3%)
#   adding: dataset-pdf/377/images/Figure_2.png (deflated 4%)
#   adding: dataset-pdf/377/images/Table_2.png (deflated 6%)
#   adding: dataset-pdf/377/images/Figure_3.png (deflated 4%)
#   adding: dataset-pdf/377/images/Table_4.png (deflated 4%)
#   adding: dataset-pdf/377/images/Table_3.png (deflated 7%)
#   adding: dataset-pdf/377/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/377/slide.pdf (deflated 13%)
#   adding: dataset-pdf/377/paper.tei.xml (deflated 78%)
#   adding: dataset-pdf/377/453.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/377/extracted_text.txt (deflated 68%)
#   adding: dataset-pdf/377/paper.pdf (deflated 10%)
#   adding: dataset-pdf/377/slide.xml (deflated 72%)
#   adding: dataset-pdf/377/slide.md (deflated 63%)
#   adding: dataset-pdf/377/figures_and_tables.txt (deflated 59%)
#   adding: dataset-pdf/377/input_prompt.txt (deflated 69%)
#   adding: dataset-pdf/377/extracted_text_with_tag.txt (deflated 68%)
#   adding: dataset-pdf/466/ (stored 0%)
#   adding: dataset-pdf/466/images/ (stored 0%)
#   adding: dataset-pdf/466/images/Table_1.png (deflated 6%)
#   adding: dataset-pdf/466/images/Figure_2.png (deflated 3%)
#   adding: dataset-pdf/466/images/Figure_1.png (deflated 7%)
#   adding: dataset-pdf/466/slide.pdf (deflated 18%)
#   adding: dataset-pdf/466/paper.tei.xml (deflated 77%)
#   adding: dataset-pdf/466/extracted_text.txt (deflated 69%)
#   adding: dataset-pdf/466/paper.pdf (deflated 31%)
#   adding: dataset-pdf/466/slide.xml (deflated 76%)
#   adding: dataset-pdf/466/slide.md (deflated 65%)
#   adding: dataset-pdf/466/figures_and_tables.txt (deflated 44%)
#   adding: dataset-pdf/466/input_prompt.txt (deflated 69%)
#   adding: dataset-pdf/466/566.windowed_summarunner_scores.txt (deflated 87%)
#   adding: dataset-pdf/466/extracted_text_with_tag.txt (deflated 69%)
#   adding: dataset-pdf/1079/ (stored 0%)
#   adding: dataset-pdf/1079/1296.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/1079/images/ (stored 0%)
#   adding: dataset-pdf/1079/images/Table_1.png (deflated 5%)
#   adding: dataset-pdf/1079/images/Figure_4.png (deflated 5%)
#   adding: dataset-pdf/1079/images/Figure_5.png (deflated 4%)
#   adding: dataset-pdf/1079/images/Figure_2.png (deflated 5%)
#   adding: dataset-pdf/1079/images/Table_2.png (deflated 5%)
#   adding: dataset-pdf/1079/images/Figure_3.png (deflated 4%)
#   adding: dataset-pdf/1079/images/Table_3.png (deflated 4%)
#   adding: dataset-pdf/1079/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/1079/slide.pdf (deflated 4%)
#   adding: dataset-pdf/1079/paper.tei.xml (deflated 77%)
#   adding: dataset-pdf/1079/extracted_text.txt (deflated 69%)
#   adding: dataset-pdf/1079/paper.pdf (deflated 7%)
#   adding: dataset-pdf/1079/slide.xml (deflated 64%)
#   adding: dataset-pdf/1079/slide.md (deflated 56%)
#   adding: dataset-pdf/1079/figures_and_tables.txt (deflated 61%)
#   adding: dataset-pdf/1079/input_prompt.txt (deflated 69%)
#   adding: dataset-pdf/1079/extracted_text_with_tag.txt (deflated 69%)
#   adding: dataset-pdf/290/ (stored 0%)
#   adding: dataset-pdf/290/images/ (stored 0%)
#   adding: dataset-pdf/290/images/Table_1.png (deflated 5%)
#   adding: dataset-pdf/290/images/Figure_4.png (deflated 6%)
#   adding: dataset-pdf/290/images/Table_5.png (deflated 7%)
#   adding: dataset-pdf/290/images/Table_6.png (deflated 7%)
#   adding: dataset-pdf/290/images/Figure_2.png (deflated 7%)
#   adding: dataset-pdf/290/images/Table_2.png (deflated 7%)
#   adding: dataset-pdf/290/images/Figure_3.png (deflated 9%)
#   adding: dataset-pdf/290/images/Table_4.png (deflated 8%)
#   adding: dataset-pdf/290/images/Table_3.png (deflated 9%)
#   adding: dataset-pdf/290/images/Figure_1.png (deflated 6%)
#   adding: dataset-pdf/290/slide.pdf (deflated 10%)
#   adding: dataset-pdf/290/paper.tei.xml (deflated 76%)
#   adding: dataset-pdf/290/extracted_text.txt (deflated 65%)
#   adding: dataset-pdf/290/paper.pdf (deflated 8%)
#   adding: dataset-pdf/290/slide.xml (deflated 77%)
#   adding: dataset-pdf/290/slide.md (deflated 64%)
#   adding: dataset-pdf/290/figures_and_tables.txt (stored 0%)
#   adding: dataset-pdf/290/input_prompt.txt (deflated 65%)
#   adding: dataset-pdf/290/340.windowed_summarunner_scores.txt (deflated 84%)
#   adding: dataset-pdf/290/extracted_text_with_tag.txt (deflated 65%)
#   adding: dataset-pdf/559/ (stored 0%)
#   adding: dataset-pdf/559/images/ (stored 0%)
#   adding: dataset-pdf/559/images/Table_1.png (deflated 5%)
#   adding: dataset-pdf/559/images/Figure_4.png (deflated 4%)
#   adding: dataset-pdf/559/images/Figure_6.png (deflated 4%)
#   adding: dataset-pdf/559/images/Figure_5.png (deflated 5%)
#   adding: dataset-pdf/559/images/Figure_2.png (deflated 7%)
#   adding: dataset-pdf/559/images/Table_2.png (deflated 3%)
#   adding: dataset-pdf/559/images/Figure_3.png (deflated 5%)
#   adding: dataset-pdf/559/images/Figure_1.png (deflated 5%)
#   adding: dataset-pdf/559/images/Figure_7.png (deflated 4%)
#   adding: dataset-pdf/559/slide.pdf (deflated 11%)
#   adding: dataset-pdf/559/669.windowed_summarunner_scores.txt (deflated 89%)
#   adding: dataset-pdf/559/paper.tei.xml (deflated 76%)
#   adding: dataset-pdf/559/extracted_text.txt (deflated 69%)
#   adding: dataset-pdf/559/paper.pdf (deflated 15%)
#   adding: dataset-pdf/559/slide.xml (deflated 71%)
#   adding: dataset-pdf/559/slide.md (deflated 61%)
#   adding: dataset-pdf/559/figures_and_tables.txt (deflated 51%)
#   adding: dataset-pdf/559/input_prompt.txt (deflated 69%)
#   adding: dataset-pdf/559/extracted_text_with_tag.txt (deflated 69%)
#   adding: dataset-pdf/1020/ (stored 0%)
#   adding: dataset-pdf/1020/images/ (stored 0%)
#   adding: dataset-pdf/1020/images/Figure_1.png (deflated 4%)
#   adding: dataset-pdf/1020/slide.pdf (deflated 9%)
#   adding: dataset-pdf/1020/paper.tei.xml (deflated 75%)
#   adding: dataset-pdf/1020/extracted_text.txt (deflated 62%)
#   adding: dataset-pdf/1020/paper.pdf (deflated 8%)
#   adding: dataset-pdf/1020/slide.xml (deflated 63%)
#   adding: dataset-pdf/1020/1231.windowed_summarunner_scores.txt (deflated 83%)
#   adding: dataset-pdf/1020/slide.md (deflated 57%)
#   adding: dataset-pdf/1020/figures_and_tables.txt (deflated 12%)
#   adding: dataset-pdf/1020/input_prompt.txt (deflated 62%)
#   adding: dataset-pdf/1020/extracted_text_with_tag.txt (deflated 62%)
#   adding: dataset-pdf/711/ (stored 0%)
#   adding: dataset-pdf/711/images/ (stored 0%)
#   adding: dataset-pdf/711/images/Figure_4.png (deflated 7%)
#   adding: dataset-pdf/711/images/Figure_6.png (deflated 2%)
#   adding: dataset-pdf/711/images/Figure_5.png (deflated 3%)
#   adding: dataset-pdf/711/images/Figure_2.png (deflated 6%)
#   adding: dataset-pdf/711/images/Figure_3.png (deflated 7%)
#   adding: dataset-pdf/711/images/Figure_1.png (deflated 5%)
#   adding: dataset-pdf/711/slide.pdf (deflated 61%)
#   adding: dataset-pdf/711/paper.tei.xml (deflated 71%)
#   adding: dataset-pdf/711/extracted_text.txt (deflated 49%)
#   adding: dataset-pdf/711/854.windowed_summarunner_scores.txt (deflated 90%)
#   adding: dataset-pdf/711/paper.pdf (deflated 22%)
#   adding: dataset-pdf/711/slide.xml (deflated 66%)
#   adding: dataset-pdf/711/slide.md (deflated 60%)
#   adding: dataset-pdf/711/figures_and_tables.txt (deflated 57%)
#   adding: dataset-pdf/711/input_prompt.txt (deflated 55%)
#   adding: dataset-pdf/711/extracted_text_with_tag.txt (deflated 49%)
#   adding: dataset-pdf/488/ (stored 0%)
#   adding: dataset-pdf/488/images/ (stored 0%)
#   adding: dataset-pdf/488/slide.pdf (deflated 22%)
#   adding: dataset-pdf/488/paper.tei.xml (deflated 73%)
#   adding: dataset-pdf/488/extracted_text.txt (deflated 63%)
#   adding: dataset-pdf/488/paper.pdf (deflated 4%)
#   adding: dataset-pdf/488/slide.xml (deflated 71%)
#   adding: dataset-pdf/488/slide.md (deflated 67%)
#   adding: dataset-pdf/488/figures_and_tables.txt (stored 0%)
#   adding: dataset-pdf/488/input_prompt.txt (deflated 63%)
#   adding: dataset-pdf/488/extracted_text_with_tag.txt (deflated 63%)
#   adding: dataset-pdf/488/592.windowed_summarunner_scores.txt (deflated 82%)
#   adding: dataset-pdf/257/ (stored 0%)
#   adding: dataset-pdf/257/302.windowed_summarunner_scores.txt (deflated 92%)
#   adding: dataset-pdf/257/images/ (stored 0%)
#   adding: dataset-pdf/257/images/Table_1.png (deflated 3%)
#   adding: dataset-pdf/257/images/Figure_4.png (deflated 4%)
#   adding: dataset-pdf/257/images/Figure_6.png (deflated 3%)
#   adding: dataset-pdf/257/images/Figure_9.png (deflated 3%)
#   adding: dataset-pdf/257/images/Figure_5.png (deflated 3%)
#   adding: dataset-pdf/257/images/Figure_2.png (deflated 3%)
#   adding: dataset-pdf/257/images/Figure_3.png (deflated 4%)
#   adding: dataset-pdf/257/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/257/images/Figure_8.png (deflated 5%)
#   adding: dataset-pdf/257/images/Figure_10.png (deflated 3%)
#   adding: dataset-pdf/257/images/Figure_7.png (deflated 4%)
#   adding: dataset-pdf/257/slide.pdf (deflated 14%)
#   adding: dataset-pdf/257/paper.tei.xml (deflated 76%)
#   adding: dataset-pdf/257/extracted_text.txt (deflated 70%)
#   adding: dataset-pdf/257/paper.pdf (deflated 15%)
#   adding: dataset-pdf/257/slide.xml (deflated 72%)
#   adding: dataset-pdf/257/slide.md (deflated 63%)
#   adding: dataset-pdf/257/figures_and_tables.txt (deflated 57%)
#   adding: dataset-pdf/257/input_prompt.txt (deflated 70%)
#   adding: dataset-pdf/257/extracted_text_with_tag.txt (deflated 70%)
#   adding: dataset-pdf/246/ (stored 0%)
#   adding: dataset-pdf/246/images/ (stored 0%)
#   adding: dataset-pdf/246/images/Figure_4.png (deflated 3%)
#   adding: dataset-pdf/246/images/Figure_6.png (deflated 3%)
#   adding: dataset-pdf/246/images/Figure_5.png (deflated 4%)
#   adding: dataset-pdf/246/images/Figure_2.png (deflated 5%)
#   adding: dataset-pdf/246/images/Figure_3.png (deflated 4%)
#   adding: dataset-pdf/246/images/Figure_1.png (deflated 5%)
#   adding: dataset-pdf/246/images/Figure_7.png (deflated 7%)
#   adding: dataset-pdf/246/slide.pdf (deflated 14%)
#   adding: dataset-pdf/246/paper.tei.xml (deflated 76%)
#   adding: dataset-pdf/246/extracted_text.txt (deflated 70%)
#   adding: dataset-pdf/246/paper.pdf (deflated 6%)
#   adding: dataset-pdf/246/289.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/246/slide.xml (deflated 72%)
#   adding: dataset-pdf/246/slide.md (deflated 67%)
#   adding: dataset-pdf/246/figures_and_tables.txt (deflated 51%)
#   adding: dataset-pdf/246/input_prompt.txt (deflated 70%)
#   adding: dataset-pdf/246/extracted_text_with_tag.txt (deflated 70%)
#   adding: dataset-pdf/977/ (stored 0%)
#   adding: dataset-pdf/977/images/ (stored 0%)
#   adding: dataset-pdf/977/images/Figure_4.png (deflated 5%)
#   adding: dataset-pdf/977/images/Figure_12.png (deflated 6%)
#   adding: dataset-pdf/977/images/Figure_6.png (deflated 3%)
#   adding: dataset-pdf/977/images/Figure_9.png (deflated 5%)
#   adding: dataset-pdf/977/images/Figure_5.png (deflated 6%)
#   adding: dataset-pdf/977/images/Figure_2.png (deflated 5%)
#   adding: dataset-pdf/977/images/Figure_3.png (deflated 5%)
#   adding: dataset-pdf/977/images/Figure_11.png (deflated 9%)
# ...
#   adding: dataset-pdf/581/slide.pdf (deflated 16%)
#   adding: dataset-pdf/581/paper.tei.xml (deflated 74%)
#   adding: dataset-pdf/581/extracted_text.txt (deflated 68%)
#   adding: dataset-pdf/581/paper.pdf (deflated 16%)
#   adding: dataset-pdf/581/slide.xml (deflated 65%)
#   adding: dataset-pdf/581/slide.md (deflated 68%)
#   adding: dataset-pdf/581/694.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/581/figures_and_tables.txt (deflated 53%)
#   adding: dataset-pdf/581/input_prompt.txt (deflated 68%)
#   adding: dataset-pdf/581/extracted_text_with_tag.txt (deflated 68%)
#   adding: dataset-pdf/347/ (stored 0%)
#   adding: dataset-pdf/347/415.windowed_summarunner_scores.txt (deflated 87%)
#   adding: dataset-pdf/347/images/ (stored 0%)
#   adding: dataset-pdf/347/slide.pdf (deflated 11%)
#   adding: dataset-pdf/347/paper.tei.xml (deflated 75%)
#   adding: dataset-pdf/347/extracted_text.txt (deflated 65%)
#   adding: dataset-pdf/347/paper.pdf (deflated 24%)
#   adding: dataset-pdf/347/slide.xml (deflated 68%)
#   adding: dataset-pdf/347/slide.md (deflated 57%)
#   adding: dataset-pdf/347/figures_and_tables.txt (stored 0%)
#   adding: dataset-pdf/347/input_prompt.txt (deflated 65%)
#   adding: dataset-pdf/347/extracted_text_with_tag.txt (deflated 65%)
#   adding: dataset-pdf/674/ (stored 0%)
#   adding: dataset-pdf/674/images/ (stored 0%)
#   adding: dataset-pdf/674/slide.pdf (deflated 5%)
#   adding: dataset-pdf/674/paper.tei.xml (deflated 74%)
#   adding: dataset-pdf/674/806.windowed_summarunner_scores.txt (deflated 84%)
#   adding: dataset-pdf/674/extracted_text.txt (deflated 65%)
#   adding: dataset-pdf/674/paper.pdf (deflated 16%)
#   adding: dataset-pdf/674/slide.xml (deflated 72%)
#   adding: dataset-pdf/674/slide.md (deflated 63%)
#   adding: dataset-pdf/674/figures_and_tables.txt (stored 0%)
#   adding: dataset-pdf/674/input_prompt.txt (deflated 65%)
#   adding: dataset-pdf/674/extracted_text_with_tag.txt (deflated 65%)
#   adding: dataset-pdf/129/ (stored 0%)
#   adding: dataset-pdf/129/images/ (stored 0%)
#   adding: dataset-pdf/129/images/Figure_4.png (deflated 2%)
#   adding: dataset-pdf/129/images/Figure_12.png (deflated 6%)
#   adding: dataset-pdf/129/images/Figure_9.png (deflated 6%)
#   adding: dataset-pdf/129/images/Figure_5.png (deflated 6%)
#   adding: dataset-pdf/129/images/Figure_2.png (deflated 4%)
#   adding: dataset-pdf/129/images/Figure_3.png (deflated 5%)
#   adding: dataset-pdf/129/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/129/images/Figure_8.png (deflated 5%)
#   adding: dataset-pdf/129/images/Figure_10.png (deflated 4%)
#   adding: dataset-pdf/129/images/Figure_7.png (deflated 5%)
#   adding: dataset-pdf/129/slide.pdf (deflated 6%)
#   adding: dataset-pdf/129/paper.tei.xml (deflated 77%)
#   adding: dataset-pdf/129/extracted_text.txt (deflated 67%)
#   adding: dataset-pdf/129/paper.pdf (deflated 8%)
#   adding: dataset-pdf/129/slide.xml (deflated 61%)
#   adding: dataset-pdf/129/slide.md (deflated 53%)
#   adding: dataset-pdf/129/figures_and_tables.txt (deflated 54%)
#   adding: dataset-pdf/129/147.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/129/input_prompt.txt (deflated 67%)
#   adding: dataset-pdf/129/extracted_text_with_tag.txt (deflated 67%)
#   adding: dataset-pdf/532/ (stored 0%)
#   adding: dataset-pdf/532/images/ (stored 0%)
#   adding: dataset-pdf/532/images/Figure_2.png (deflated 5%)
#   adding: dataset-pdf/532/images/Figure_1.png (deflated 6%)
#   adding: dataset-pdf/532/slide.pdf (deflated 22%)
#   adding: dataset-pdf/532/639.windowed_summarunner_scores.txt (deflated 86%)
#   adding: dataset-pdf/532/paper.tei.xml (deflated 74%)
#   adding: dataset-pdf/532/extracted_text.txt (deflated 64%)
#   adding: dataset-pdf/532/paper.pdf (deflated 13%)
#   adding: dataset-pdf/532/slide.xml (deflated 61%)
#   adding: dataset-pdf/532/slide.md (deflated 55%)
#   adding: dataset-pdf/532/figures_and_tables.txt (deflated 33%)
#   adding: dataset-pdf/532/input_prompt.txt (deflated 64%)
#   adding: dataset-pdf/532/extracted_text_with_tag.txt (deflated 64%)
#   adding: dataset-pdf/899/ (stored 0%)
#   adding: dataset-pdf/899/images/ (stored 0%)
#   adding: dataset-pdf/899/slide.pdf (deflated 62%)
#   adding: dataset-pdf/899/1087.windowed_summarunner_scores.txt (deflated 89%)
#   adding: dataset-pdf/899/paper.tei.xml (deflated 69%)
#   adding: dataset-pdf/899/extracted_text.txt (deflated 65%)
#   adding: dataset-pdf/899/paper.pdf (deflated 11%)
#   adding: dataset-pdf/899/slide.xml (deflated 81%)
#   adding: dataset-pdf/899/slide.md (deflated 62%)
#   adding: dataset-pdf/899/figures_and_tables.txt (stored 0%)
#   adding: dataset-pdf/899/input_prompt.txt (deflated 65%)
#   adding: dataset-pdf/899/extracted_text_with_tag.txt (deflated 65%)
#   adding: dataset-pdf/136/ (stored 0%)
#   adding: dataset-pdf/136/images/ (stored 0%)
#   adding: dataset-pdf/136/images/Table_I.png (deflated 7%)
#   adding: dataset-pdf/136/images/Figure_4.png (deflated 5%)
#   adding: dataset-pdf/136/images/Figure_6.png (deflated 3%)
#   adding: dataset-pdf/136/images/Figure_2.png (deflated 3%)
#   adding: dataset-pdf/136/images/Figure_3.png (deflated 3%)
#   adding: dataset-pdf/136/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/136/images/Figure_8.png (deflated 3%)
#   adding: dataset-pdf/136/slide.pdf (deflated 7%)
#   adding: dataset-pdf/136/paper.tei.xml (deflated 75%)
#   adding: dataset-pdf/136/extracted_text.txt (deflated 53%)
#   adding: dataset-pdf/136/paper.pdf (deflated 12%)
#   adding: dataset-pdf/136/slide.xml (deflated 66%)
#   adding: dataset-pdf/136/slide.md (deflated 61%)
#   adding: dataset-pdf/136/figures_and_tables.txt (deflated 47%)
#   adding: dataset-pdf/136/input_prompt.txt (deflated 55%)
#   adding: dataset-pdf/136/extracted_text_with_tag.txt (deflated 52%)
#   adding: dataset-pdf/136/155.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/907/ (stored 0%)
#   adding: dataset-pdf/907/images/ (stored 0%)
#   adding: dataset-pdf/907/images/Table_1.png (deflated 5%)
#   adding: dataset-pdf/907/images/Figure_4.png (deflated 4%)
#   adding: dataset-pdf/907/images/Figure_2.png (deflated 1%)
#   adding: dataset-pdf/907/images/Figure_3.png (deflated 4%)
#   adding: dataset-pdf/907/images/Figure_1.png (deflated 4%)
#   adding: dataset-pdf/907/slide.pdf (deflated 19%)
#   adding: dataset-pdf/907/paper.tei.xml (deflated 69%)
#   adding: dataset-pdf/907/extracted_text.txt (deflated 63%)
#   adding: dataset-pdf/907/paper.pdf (deflated 51%)
#   adding: dataset-pdf/907/1099.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/907/slide.xml (deflated 72%)
#   adding: dataset-pdf/907/slide.md (deflated 58%)
#   adding: dataset-pdf/907/figures_and_tables.txt (deflated 46%)
#   adding: dataset-pdf/907/input_prompt.txt (deflated 63%)
#   adding: dataset-pdf/907/extracted_text_with_tag.txt (deflated 63%)
#   adding: dataset-pdf/1060/ (stored 0%)
#   adding: dataset-pdf/1060/images/ (stored 0%)
#   adding: dataset-pdf/1060/images/Table_1.png (deflated 10%)
#   adding: dataset-pdf/1060/images/Figure_4.png (deflated 4%)
#   adding: dataset-pdf/1060/images/Figure_2.png (deflated 7%)
#   adding: dataset-pdf/1060/images/Figure_3.png (deflated 3%)
#   adding: dataset-pdf/1060/images/Figure_1.png (deflated 5%)
#   adding: dataset-pdf/1060/slide.pdf (deflated 9%)
#   adding: dataset-pdf/1060/paper.tei.xml (deflated 74%)
#   adding: dataset-pdf/1060/extracted_text.txt (deflated 65%)
#   adding: dataset-pdf/1060/paper.pdf (deflated 19%)
#   adding: dataset-pdf/1060/slide.xml (deflated 63%)
#   adding: dataset-pdf/1060/slide.md (deflated 55%)
#   adding: dataset-pdf/1060/figures_and_tables.txt (deflated 51%)
#   adding: dataset-pdf/1060/input_prompt.txt (deflated 66%)
#   adding: dataset-pdf/1060/1276.windowed_summarunner_scores.txt (deflated 83%)
#   adding: dataset-pdf/1060/extracted_text_with_tag.txt (deflated 65%)
#   adding: dataset-pdf/648/ (stored 0%)
#   adding: dataset-pdf/648/images/ (stored 0%)
#   adding: dataset-pdf/648/images/Table_1.png (deflated 5%)
#   adding: dataset-pdf/648/images/Table_2.png (deflated 10%)
#   adding: dataset-pdf/648/images/Table_3.png (deflated 7%)
#   adding: dataset-pdf/648/slide.pdf (deflated 6%)
#   adding: dataset-pdf/648/paper.tei.xml (deflated 70%)
#   adding: dataset-pdf/648/extracted_text.txt (deflated 59%)
#   adding: dataset-pdf/648/paper.pdf (deflated 15%)
#   adding: dataset-pdf/648/slide.xml (deflated 77%)
#   adding: dataset-pdf/648/slide.md (deflated 59%)
#   adding: dataset-pdf/648/figures_and_tables.txt (deflated 34%)
#   adding: dataset-pdf/648/input_prompt.txt (deflated 59%)
#   adding: dataset-pdf/648/769.windowed_summarunner_scores.txt (deflated 84%)
#   adding: dataset-pdf/648/extracted_text_with_tag.txt (deflated 59%)
#   adding: dataset-pdf/831/ (stored 0%)
#   adding: dataset-pdf/831/images/ (stored 0%)
#   adding: dataset-pdf/831/images/Figure_2.png (deflated 5%)
#   adding: dataset-pdf/831/images/Figure_1.png (deflated 4%)
#   adding: dataset-pdf/831/slide.pdf (deflated 38%)
#   adding: dataset-pdf/831/996.windowed_summarunner_scores.txt (deflated 86%)
#   adding: dataset-pdf/831/paper.tei.xml (deflated 74%)
#   adding: dataset-pdf/831/extracted_text.txt (deflated 68%)
#   adding: dataset-pdf/831/paper.pdf (deflated 6%)
#   adding: dataset-pdf/831/slide.xml (deflated 90%)
#   adding: dataset-pdf/831/slide.md (deflated 58%)
#   adding: dataset-pdf/831/figures_and_tables.txt (deflated 42%)
#   adding: dataset-pdf/831/input_prompt.txt (deflated 68%)
#   adding: dataset-pdf/831/extracted_text_with_tag.txt (deflated 68%)
#   adding: dataset-pdf/649/ (stored 0%)
#   adding: dataset-pdf/649/images/ (stored 0%)
#   adding: dataset-pdf/649/images/Table_1.png (deflated 5%)
#   adding: dataset-pdf/649/images/Figure_4.png (deflated 15%)
#   adding: dataset-pdf/649/images/Figure_6.png (deflated 5%)
#   adding: dataset-pdf/649/images/Figure_5.png (deflated 5%)
#   adding: dataset-pdf/649/images/Figure_2.png (deflated 7%)
#   adding: dataset-pdf/649/images/Table_2.png (deflated 5%)
#   adding: dataset-pdf/649/images/Figure_3.png (deflated 7%)
#   adding: dataset-pdf/649/images/Figure_1.png (deflated 3%)
#   adding: dataset-pdf/649/slide.pdf (deflated 20%)
#   adding: dataset-pdf/649/paper.tei.xml (deflated 73%)
#   adding: dataset-pdf/649/extracted_text.txt (deflated 65%)
#   adding: dataset-pdf/649/paper.pdf (deflated 7%)
#   adding: dataset-pdf/649/slide.xml (deflated 82%)
#   adding: dataset-pdf/649/slide.md (deflated 69%)
#   adding: dataset-pdf/649/770.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/649/figures_and_tables.txt (deflated 51%)
#   adding: dataset-pdf/649/input_prompt.txt (deflated 65%)
#   adding: dataset-pdf/649/extracted_text_with_tag.txt (deflated 65%)
#   adding: dataset-pdf/986/ (stored 0%)
#   adding: dataset-pdf/986/images/ (stored 0%)
#   adding: dataset-pdf/986/slide.pdf (deflated 3%)
#   adding: dataset-pdf/986/paper.tei.xml (deflated 71%)
#   adding: dataset-pdf/986/extracted_text.txt (deflated 62%)
#   adding: dataset-pdf/986/paper.pdf (deflated 12%)
#   adding: dataset-pdf/986/slide.xml (deflated 65%)
#   adding: dataset-pdf/986/slide.md (deflated 58%)
#   adding: dataset-pdf/986/figures_and_tables.txt (stored 0%)
#   adding: dataset-pdf/986/input_prompt.txt (deflated 62%)
#   adding: dataset-pdf/986/1197.windowed_summarunner_scores.txt (deflated 85%)
#   adding: dataset-pdf/986/extracted_text_with_tag.txt (deflated 62%)
#   adding: dataset-pdf/446/ (stored 0%)
#   adding: dataset-pdf/446/images/ (stored 0%)
#   adding: dataset-pdf/446/images/Table_1.png (deflated 4%)
#   adding: dataset-pdf/446/images/Figure_4.png (deflated 7%)
#   adding: dataset-pdf/446/images/Figure_6.png (deflated 7%)
#   adding: dataset-pdf/446/images/Figure_5.png (deflated 7%)
#   adding: dataset-pdf/446/images/Figure_2.png (deflated 3%)
#   adding: dataset-pdf/446/images/Table_2.png (deflated 6%)
#   adding: dataset-pdf/446/images/Figure_3.png (deflated 4%)
#   adding: dataset-pdf/446/images/Table_4.png (deflated 12%)
#   adding: dataset-pdf/446/images/Table_3.png (deflated 9%)
#   adding: dataset-pdf/446/images/Figure_1.png (deflated 8%)
#   adding: dataset-pdf/446/images/Figure_7.png (deflated 7%)
#   adding: dataset-pdf/446/slide.pdf (deflated 17%)
#   adding: dataset-pdf/446/546.windowed_summarunner_scores.txt (deflated 89%)
#   adding: dataset-pdf/446/paper.tei.xml (deflated 74%)
#   adding: dataset-pdf/446/extracted_text.txt (deflated 67%)
#   adding: dataset-pdf/446/paper.pdf (deflated 68%)
#   adding: dataset-pdf/446/slide.xml (deflated 73%)
#   adding: dataset-pdf/446/slide.md (deflated 62%)
#   adding: dataset-pdf/446/figures_and_tables.txt (deflated 60%)
#   adding: dataset-pdf/446/input_prompt.txt (deflated 67%)
#   adding: dataset-pdf/446/extracted_text_with_tag.txt (deflated 67%)
#   adding: dataset-pdf/287/ (stored 0%)
#   adding: dataset-pdf/287/images/ (stored 0%)
#   adding: dataset-pdf/287/images/Table_1.png (deflated 3%)
#   adding: dataset-pdf/287/images/Figure_2.png (deflated 1%)
#   adding: dataset-pdf/287/images/Table_2.png (deflated 4%)
#   adding: dataset-pdf/287/images/Figure_1.png (deflated 2%)
#   adding: dataset-pdf/287/337.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/287/slide.pdf (deflated 21%)
#   adding: dataset-pdf/287/paper.tei.xml (deflated 68%)
#   adding: dataset-pdf/287/extracted_text.txt (deflated 63%)
#   adding: dataset-pdf/287/paper.pdf (deflated 1%)
#   adding: dataset-pdf/287/slide.xml (deflated 91%)
#   adding: dataset-pdf/287/slide.md (deflated 58%)
#   adding: dataset-pdf/287/figures_and_tables.txt (deflated 15%)
#   adding: dataset-pdf/287/input_prompt.txt (deflated 63%)
#   adding: dataset-pdf/287/extracted_text_with_tag.txt (deflated 63%)
#   adding: dataset-pdf/43/ (stored 0%)
#   adding: dataset-pdf/43/images/ (stored 0%)
#   adding: dataset-pdf/43/images/Figure_4.png (deflated 5%)
#   adding: dataset-pdf/43/images/Figure_6.png (deflated 2%)
#   adding: dataset-pdf/43/images/Figure_9.png (deflated 4%)
#   adding: dataset-pdf/43/images/Figure_2.png (deflated 3%)
#   adding: dataset-pdf/43/images/Figure_3.png (deflated 3%)
#   adding: dataset-pdf/43/images/Figure_1.png (deflated 4%)
#   adding: dataset-pdf/43/images/Figure_8.png (deflated 4%)
#   adding: dataset-pdf/43/images/Figure_7.png (deflated 3%)
#   adding: dataset-pdf/43/slide.pdf (deflated 12%)
#   adding: dataset-pdf/43/paper.tei.xml (deflated 72%)
#   adding: dataset-pdf/43/extracted_text.txt (deflated 67%)
#   adding: dataset-pdf/43/paper.pdf (deflated 7%)
#   adding: dataset-pdf/43/slide.xml (deflated 70%)
#   adding: dataset-pdf/43/slide.md (deflated 63%)
#   adding: dataset-pdf/43/figures_and_tables.txt (deflated 34%)
#   adding: dataset-pdf/43/input_prompt.txt (deflated 67%)
#   adding: dataset-pdf/43/extracted_text_with_tag.txt (deflated 67%)
#   adding: dataset-pdf/43/50.windowed_summarunner_scores.txt (deflated 88%)
#   adding: dataset-pdf/1069/ (stored 0%)
#   adding: dataset-pdf/1069/images/ (stored 0%)
#   adding: dataset-pdf/1069/images/Figure_4.png (deflated 7%)
#   adding: dataset-pdf/1069/images/Figure_12.png (deflated 9%)
#   adding: dataset-pdf/1069/images/Figure_6.png (deflated 8%)
#   adding: dataset-pdf/1069/images/Figure_9.png (deflated 13%)
#   adding: dataset-pdf/1069/images/Figure_5.png (deflated 11%)
#   adding: dataset-pdf/1069/images/Figure_2.png (deflated 6%)
#   adding: dataset-pdf/1069/images/Figure_3.png (deflated 6%)
#   adding: dataset-pdf/1069/images/Figure_11.png (deflated 7%)
#   adding: dataset-pdf/1069/images/Figure_1.png (deflated 7%)
#   adding: dataset-pdf/1069/images/Figure_8.png (deflated 10%)
#   adding: dataset-pdf/1069/images/Figure_10.png (deflated 9%)
#   adding: dataset-pdf/1069/images/Figure_7.png (deflated 11%)
#   adding: dataset-pdf/1069/slide.pdf (deflated 14%)
#   adding: dataset-pdf/1069/paper.tei.xml (deflated 70%)
#   adding: dataset-pdf/1069/extracted_text.txt (deflated 62%)
#   adding: dataset-pdf/1069/paper.pdf (deflated 6%)
#   adding: dataset-pdf/1069/slide.xml (deflated 68%)
#   adding: dataset-pdf/1069/slide.md (deflated 58%)
#   adding: dataset-pdf/1069/figures_and_tables.txt (deflated 56%)
#   adding: dataset-pdf/1069/input_prompt.txt (deflated 64%)
#   adding: dataset-pdf/1069/1285.windowed_summarunner_scores.txt (deflated 86%)
#   adding: dataset-pdf/1069/extracted_text_with_tag.txt (deflated 62%)

# %%
# !cp dataset-pdf-clean.zip "/content/drive/MyDrive/nlp/dataset-pdf-zip.zip"

# %%
instruction = f"""FROM:
{slide_md_text}
You will have to cleanup slide text above to easier to understand. If you saw duplicate slide you will have to remove it too.Each slide should cover a complete topic or subtopic, not incremental additions.
For example, if a topic like "Introduction" has several bullet points, combine them into one slide titled "Introduction", rather than creating separate slides for each point.
Keep slide titles concise and avoid repeating titles across multiple slides. You will have to output slide text with ```markdown ``` format. do not include unnecessary text such as Okay. you will have to adjust slide text According to slidev or https://github.com/slidevjs/slidev"""
print(generate_content_with_rate_limit(instruction))
# Out:
# ```markdown
# ---
# theme: default
# title: Matrix-Vector Multiplication in Sub-Quadratic Time (Some Preprocessing Required)
# class: text-center
# ---
#
# # Matrix-Vector Multiplication in Sub-Quadratic Time
# Ryan Williams
#
# ---
#
# # Introduction
#
# Matrix-vector multiplication is a fundamental operation in scientific computing. The question is: How fast can an n x n matrix-vector multiplication be performed? Note that it takes O(n²) steps just to read the matrix!
#
# ---
#
# # Main Result
#
# If we allow O(n²⁺ε) preprocessing, then matrix-vector multiplication over any finite semiring can be done in O(n²/(log n)²).
#
# ---
#
# # Better Algorithms for Matrix Multiplication
#
# Three major developments in matrix multiplication algorithms:
#
# *   Arlazarov et al. (Four Russians, 1960s): O(n³/log n) operations. Uses table lookups, good for hardware with short vector operations as primitives.
# *   Strassen (1969): O(n^log₂7) = O(n².⁸¹) operations. Asymptotically fast, but overhead exists. Experiments are inconclusive about Strassen vs. Four Russians for Boolean matrix multiplication (Bard, 2006).
# *   Coppersmith and Winograd (1990): O(n².³⁷⁶) operations. Not yet practical.
#
# ---
#
# # Focus: Combinatorial Matrix Multiplication Algorithms
#
# These are also called non-algebraic or non-subtractive algorithms (e.g., Four-Russians is combinatorial, Strassen isn't).
#
# ---
#
# # More Non-Subtractive Boolean Matrix Multiplication Algorithms
#
# *   Atkinson and Santoro: O(n³/log^(3/2) n) on a (log n)-word RAM
# *   Rytter and Basch-Khanna-Motwani: O(n³/log² n) on a RAM
# *   Chan: Four Russians can be implemented in O(n³/log² n) on a pointer machine
#
# ---
#
# # Main Result (De-amortized)
#
# The O(n³/log² n) matrix multiplication algorithm can be de-amortized.
#
# ---
#
# # Main Result (Details)
#
# We can:
#
# *   Preprocess an n x n matrix A over a finite semiring in O(n²⁺ε) time.
# *   Such that vector multiplications with A can be done in O(n²/(log n)²) time.
# *   Allows for non-subtractive matrix multiplication to be done on-line.
# *   Can be implemented on a pointer machine.
# *   This talk focuses on the Boolean case.
#
# ---
#
# # Preprocessing Phase: The Boolean Case
#
# Partition the input matrix A into blocks of log n x log n size:
#
# ```
# A =
# [ A₁,₁      A₁₂      ...  A₁,(n/log n) ]
# [ A₂,₁      A₂,₂      ...  A₂,(n/log n) ]
# [ ...       ...       ...  ...          ]
# [ A(n/log n),₁ A(n/log n),₂ ... A(n/log n),(n/log n) ]
# ```
#
# ---
#
# # Preprocessing Phase: Graph Construction
#
# Build a graph G with parts P₁, ..., P(n/log n), Q₁, ..., Q(n/log n). Each part has 2^(log n) vertices, one for each possible log n vector.
#
# ```
# P₁   P₂   ...   P(n/log n)
# 2^(log n)
# Q₁   Q₂   ...   Q(n/log n)
# ```
#
# ---
#
# # Preprocessing Phase: Edges of G
#
# Each vertex v in each Pᵢ has exactly one edge into each Qⱼ.
#
# Edge: v (in Pᵢ) -> Qⱼ is labeled with Aⱼ,ᵢ * v
#
# ---
#
# # Preprocessing Phase: Time Complexity
#
# Time to build the graph:
#
# (n/log n) * (n/log n) * 2^(log n) * (log n)² = O(n²⁺ε)
#
# (number of Qⱼ) * (number of Pᵢ) * (number of nodes in Pᵢ) * (matrix-vector mult of Aⱼ,ᵢ and v)
#
# ---
#
# # How to Do Fast Vector Multiplications
#
# Let v be a column vector. We want to compute A * v.
#
# ---
#
# # Fast Vector Multiplications: Step 1
#
# Break up v into log n sized chunks:
#
# v = [v₁, v₂, ..., v(n/log n)]
#
# ---
#
# # Fast Vector Multiplications: Step 2
#
# For each i = 1, ..., n/log n, look up vᵢ in Pᵢ. This takes O(n) time.
#
# ```
# P₁   P₂   ...   P(n/log n)
# 2^(log n)
# v₁   v₂   ...   v(n/log n)
# Q₁   Q₂   ...   Q(n/log n)
# ```
#
# ---
#
# # Fast Vector Multiplications: Step 3
#
# Look up the neighbors of vᵢ, and mark each neighbor found. This takes O(n²/(log n)²) time.
#
# ```
# P₁   P₂   ...   P(n/log n)
# 2^(log n)
# v₁   v₂   ...   v(n/log n)
# Q₁   Q₂   ...   Q(n/log n)
# A₁,₁*v₁ A₂,₂*v₂ ... A(n/log n),(n/log n)*v(n/log n)
# ```
#
# ---
#
# # Fast Vector Multiplications: Step 4
#
# For each Qⱼ, define vⱼ as the OR of all marked vectors in Qⱼ. This takes O(n¹⁺ε) time.
#
# ```
# P₁   P₂   ...   P(n/log n)
# 2^(log n)
# v₁   v₂   ...   v(n/log n)
# Q₁   Q₂   ...   Q(n/log n)
# v'₁  v'₂  ...   v'(n/log n)
# ```
#
# ---
#
# # Fast Vector Multiplications: Step 5
#
# Output v' = [v'₁, v'₂, ..., v'(n/log n)]. Claim: v' = A * v.
#
# ---
#
# # Fast Vector Multiplications: Proof
#
# By definition, v'ⱼ = ORᵢ Aⱼ,ᵢ * vᵢ.
#
# A * v =
#
# ```
# [ A₁,₁      A₁₂      ...  A₁,(n/log n) ]   [v₁]
# [ A₂,₁      A₂,₂      ...  A₂,(n/log n) ] * [v₂]
# [ ...       ...       ...  ...          ]   [...]
# [ A(n/log n),₁ A(n/log n),₂ ... A(n/log n),(n/log n) ]   [v(n/log n)]
# ```
#
# = (ORᵢ A₁,ᵢ * vᵢ, ..., ORᵢ A(n/log n),ᵢ * vᵢ) = v'
#
# ---
#
# # Some Applications
#
# Can quickly compute the neighbors of arbitrary vertex subsets. Let A be the adjacency matrix of G = (V, E). Let vS be the indicator vector for a subset S ⊆ V.
#
# ---
#
# # Neighborhood Computation
#
# Proposition: A * vS is the indicator vector for N(S), the neighborhood of S.
#
# ---
#
# # Neighborhood Corollary
#
# After O(n²⁺ε) preprocessing, can determine the neighborhood of any vertex subset in O(n²/(log n)²) time. (One level of BFS in o(n²) time)
#
# ---
#
# # Graph Queries
#
# Corollary: After O(n²⁺ε) preprocessing, can determine if a given vertex subset is an independent set, a vertex cover, or a dominating set, all in O(n²/(log n)²) time.
#
# ---
#
# # Graph Queries: Proof
#
# Let S ⊆ V.
#
# *   S is dominating ⟺ S ∪ N(S) = V.
# *   S is independent ⟺ S ∩ N(S) = ∅.
# *   S is a vertex cover ⟺ V \ S is independent.
#
# Each can be quickly determined from knowing S and N(S).
#
# ---
#
# # Triangle Detection
#
# Problem: Given a graph G and vertex i, does i participate in a 3-cycle (triangle)?
#
# ---
#
# # Triangle Detection: Naive Approach
#
# Worst Case: Can take O(n²) time to check all pairs of neighbors of i.
#
# ---
#
# # Triangle Detection: Corollary
#
# After O(n²⁺ε) preprocessing on G, can solve triangle detection for arbitrary vertices in O(n²/(log n)²) time.
#
# ---
#
# # Triangle Detection: Proof
#
# Given vertex i, let S be its set of neighbors (gotten in O(n) time). S is not independent ⟺ i participates in a triangle.
#
# ---
#
# # Conclusion
#
# A preprocessing/multiplication algorithm for matrix-vector multiplication that builds on lookup table techniques.
#
# ---
#
# # Open Questions
#
# *   Is there a preprocessing/multiplication algorithm for sparse matrices? Can we do multiplication in e.g. O(m/poly(log n) + n), where m = number of non-zeroes?
# *   Can the algebraic matrix multiplication algorithms (Strassen, etc.) be applied to this problem?
# *   Can our ideas be extended to achieve non-subtractive Boolean matrix multiplication in o(n³/log² n)?
#
# ---
#
# # Thank you!
# ```
